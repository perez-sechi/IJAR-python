# %% [markdown]
# # Median + IQR SHAP Networks for NHANES I dataset XGBoost Model
#
# This notebook implements robust aggregation using median and interquartile range (IQR) for uncertainty quantification.
#
# **Approach:** Use median instead of mean for aggregation (robust to outliers) and compute IQR to quantify variability/uncertainty in feature importance across patients. This provides both a robust summary and uncertainty bounds.
#
# ## Robust Aggregation: IQR-Inspired Percentile-Based Uncertainty
#
# We define a tolerance parameter γ ∈ [0, 50] based on the Interquartile Range (IQR). This parameter defines percentile bounds around the median:
# - We compute the (50-γ)-th and (50+γ)-th percentiles for each agent across all patients
# - When γ = 25, we obtain the classical IQR (25th and 75th percentiles)
# - The parameter γ controls how strict we are about sign consistency
#
# **Color scheme for classification:**
# - **Positive (risk) nodes:** Both percentiles are positive → at least (50+γ)% of patients have a positive effect
# - **Negative (protective) nodes:** Both percentiles are negative → at least (50+γ)% of patients have a negative effect
# - **Gray (mixed-sign) nodes:** Percentiles have different signs → tolerance band crosses zero, indicating different effects in different patients
#
# The same classification applies to interaction effects (edges).

# %%
import os
import sys
import shap
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from cgt_perezsechi.visualization.graph import draw
from cgt_perezsechi.manipulation.norm import normalize_psi, normalize_r

# %%
# Configure matplotlib for VS Code Jupyter
# %matplotlib inline
# Set pandas display options to avoid truncation
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
pd.set_option('display.max_info_columns', 99999)

# %%
# Load data
X = pd.read_pickle("../../data/nhanesi/x_values.pkl")
num_patients = 500
X_shapley = X.iloc[:num_patients, :]
shap_values = np.load("../../data/nhanesi/xgboost/shap_values.npy")
shap_interaction_values = np.load("../../data/nhanesi/xgboost/shap_interaction_values.npy")

# %% [markdown]
# ## Configuration: Tolerance Parameter γ
#
# Set the tolerance parameter γ ∈ [0, 50] for percentile-based uncertainty quantification:
# - γ = 25 → classical IQR (25th and 75th percentiles)
# - Larger γ → stricter consistency requirements (more gray nodes)
# - Smaller γ → more permissive thresholds (fewer gray nodes)

# %%
# Tolerance parameter for percentile-based uncertainty
gamma = 15  # Classical IQR when γ = 25

# Compute percentile bounds
lower_percentile = 50 - gamma  # e.g., 25th percentile when γ = 25
upper_percentile = 50 + gamma  # e.g., 75th percentile when γ = 25

print(f"Using γ = {gamma}")
print(f"Computing {lower_percentile}th and {upper_percentile}th percentiles")
print(f"This means at least {upper_percentile}% of patients must agree on sign for consistent classification")
# Out:
# Using γ = 15
# Computing 35th and 65th percentiles
# This means at least 65% of patients must agree on sign for consistent classification

# %% [markdown]
# ## Build Median-Based SHAP Values (psi_1)

# %%
shap_values_clean = np.nan_to_num(shap_values)
n_features = shap_values_clean.shape[1]

# Calculate median SHAP values across patients
median_shap = np.median(shap_values_clean, axis=0)

# Calculate percentiles using γ parameter
# When γ = 25, this gives classical IQR (25th to 75th percentile)
q_lower_shap = np.percentile(shap_values_clean, lower_percentile, axis=0)
q_upper_shap = np.percentile(shap_values_clean, upper_percentile, axis=0)
iqr_shap = q_upper_shap - q_lower_shap

# Calculate absolute median for normalization
sum_abs_median_shap = np.sum(np.abs(median_shap))

# Build psi matrices
psi_1_median = pd.DataFrame()
psi_1_median['value'] = median_shap / sum_abs_median_shap
psi_1_median['iqr'] = iqr_shap / sum_abs_median_shap
psi_1_median[f'q25'] = q_lower_shap / sum_abs_median_shap
psi_1_median[f'q75'] = q_upper_shap / sum_abs_median_shap
psi_1_median['cv'] = iqr_shap / (np.abs(median_shap) + 1e-10)  # Coefficient of variation
psi_1_median.set_index(X_shapley.columns, inplace=True)

print(f"Median-based node weights (psi) with uncertainty (γ = {gamma}):")
print(psi_1_median.head(10))
# Out:
# Median-based node weights (psi) with uncertainty (γ = 15):
#                                         value       iqr       q25       q75  \
# sex_isFemale                        -0.116573  0.246846 -0.131446  0.115401
# age                                 -0.569398  0.797690 -0.812147 -0.014458
# physical_activity                   -0.029324  0.009091 -0.033115 -0.024023
# serum_albumin                       -0.032719  0.020484 -0.036675 -0.016191
# alkaline_phosphatase                -0.000573  0.004009 -0.002028  0.001982
# alkaline_phosphatase_isUnacceptable -0.000006  0.000003 -0.000009 -0.000006
# alkaline_phosphatase_isTestnotdone  -0.000050  0.000016 -0.000056 -0.000041
# SGOT                                -0.002691  0.003264 -0.003898 -0.000634
# SGOT_isUnacceptable                 -0.000293  0.000061 -0.000320 -0.000259
# SGOT_isTestnotdone                  -0.000036  0.000010 -0.000040 -0.000030
#
#                                            cv
# sex_isFemale                         2.117515
# age                                  1.400936
# physical_activity                    0.310031
# serum_albumin                        0.626052
# alkaline_phosphatase                 6.994532
# alkaline_phosphatase_isUnacceptable  0.478191
# alkaline_phosphatase_isTestnotdone   0.310028
# SGOT                                 1.212928
# SGOT_isUnacceptable                  0.206651
# SGOT_isTestnotdone                   0.269376

# %% [markdown]
# ## Build Median-Based Interaction Values (r_1)

# %%
# Remove diagonal
n_variables = shap_interaction_values.shape[1]
filtered_shap_interaction_values = np.nan_to_num(shap_interaction_values.copy())
idx_patients = np.repeat(np.arange(num_patients), n_variables)
idx_variables = np.tile(np.arange(n_variables), num_patients)
filtered_shap_interaction_values[idx_patients, idx_variables, idx_variables] = 0

# Calculate median interaction values across patients
median_interaction = np.median(filtered_shap_interaction_values, axis=0)

# Calculate percentiles using γ parameter for interactions
q_lower_interaction = np.percentile(filtered_shap_interaction_values, lower_percentile, axis=0)
q_upper_interaction = np.percentile(filtered_shap_interaction_values, upper_percentile, axis=0)
iqr_interaction = q_upper_interaction - q_lower_interaction

# Normalize
sum_abs_median_interaction = np.sum(np.abs(median_interaction))

# Build r_1 with uncertainty
r_1_median = pd.DataFrame(median_interaction / sum_abs_median_interaction)
r_1_median.rename(columns=dict(list(zip(r_1_median.columns, X_shapley.columns))), inplace=True)
r_1_median.set_index(X_shapley.columns, inplace=True)

# Store IQR separately
r_1_iqr = pd.DataFrame(iqr_interaction / sum_abs_median_interaction)
r_1_iqr.rename(columns=dict(list(zip(r_1_iqr.columns, X_shapley.columns))), inplace=True)
r_1_iqr.set_index(X_shapley.columns, inplace=True)

print(f"\nMedian-based edge weights (r) computed with γ = {gamma}")
print(f"Mean IQR for interactions: {iqr_interaction.mean():.6f}")
# Out:
# Median-based edge weights (r) computed with γ = 15
# Mean IQR for interactions: 0.000084

# %%
# Store lower and upper percentiles for interactions
r_1_q_lower = pd.DataFrame(q_lower_interaction / sum_abs_median_interaction)
r_1_q_lower.rename(columns=dict(list(zip(r_1_q_lower.columns, X_shapley.columns))), inplace=True)
r_1_q_lower.set_index(X_shapley.columns, inplace=True)

r_1_q_upper = pd.DataFrame(q_upper_interaction / sum_abs_median_interaction)
r_1_q_upper.rename(columns=dict(list(zip(r_1_q_upper.columns, X_shapley.columns))), inplace=True)
r_1_q_upper.set_index(X_shapley.columns, inplace=True)

print(f"Lower ({lower_percentile}th) and upper ({upper_percentile}th) percentile dataframes created for interactions")
# Out:
# Lower (35th) and upper (65th) percentile dataframes created for interactions

# %% [markdown]
# ## Normalize Matrices

# %%
from IPython.display import display, Math

# Create psi_1 with just the value column for normalization
psi_1 = psi_1_median[['value']].copy()
psi_2 = normalize_psi(psi_1)
r_2 = normalize_r(r_1_median)

display(Math(r"\mathcal{N}^*_i = \frac{\mathrm{median}_t \left( Sh_{i}(\Delta^{t}) \right)}{\sum_{u=1}^{n} \left| \mathrm{median}_t \left( Sh_{u}(\Delta^{t}) \right) \right|}"))
display(psi_2)
display(Math(r"\mathcal{E}^*_{ij} = \frac{\mathrm{median}_t \left( I_{ij}(\Delta^{t}) \right)}{\sum_{v=1}^{n} \sum_{u > v}^{n} \left| \mathrm{median}_t \left( I_{uv}(\Delta^{t}) \right) \right|}"))
display(r_2)
# Out:
# $\displaystyle \mathcal{N}^*_i = \frac{\mathrm{median}_t \left( Sh_{i}(\Delta^{t}) \right)}{\sum_{u=1}^{n} \left| \mathrm{median}_t \left( Sh_{u}(\Delta^{t}) \right) \right|}$
#                                             value
# sex_isFemale                            -0.204731
# age                                     -1.000000
# physical_activity                       -0.051500
# serum_albumin                           -0.057463
# alkaline_phosphatase                    -0.001007
# alkaline_phosphatase_isUnacceptable     -0.000011
# alkaline_phosphatase_isTestnotdone      -0.000088
# SGOT                                    -0.004726
# SGOT_isUnacceptable                     -0.000515
# SGOT_isTestnotdone                      -0.000064
# BUN                                      0.003906
# BUN_isUnacceptable                      -0.000024
# BUN_isTestnotdone                       -0.000012
# calcium                                  0.001390
# calcium_isUnacceptable                  -0.000716
# calcium_isTestnotdone                   -0.000026
# creatinine                              -0.000099
# creatinine_isUnacceptable                0.000050
# creatinine_isTestnotdone                 0.000000
# potassium                                0.006528
# potassium_isUnacceptable                -0.000030
# sodium                                   0.001450
# sodium_isUnacceptable                   -0.000005
# total_bilirubin                          0.001156
# total_bilirubin_isUnacceptable          -0.000213
# total_bilirubin_isTestnotdone           -0.000015
# serum_protein                           -0.014350
# red_blood_cells                         -0.045425
# red_blood_cells_isUnacceptable          -0.006847
# red_blood_cells_isBlankbutapplicable    -0.000224
# white_blood_cells                       -0.061665
# white_blood_cells_isUnacceptable         0.000003
# white_blood_cells_isBlankbutapplicable  -0.000054
# hemoglobin                              -0.002763
# hemoglobin_isMissing                     0.000000
# hematocrit                              -0.036389
# hematocrit_isUnacceptable               -0.000558
# hematocrit_isMissing                    -0.000009
# platelets_isNormal                       0.000138
# platelets_isIncreased                   -0.000708
# platelets_isDecreased                   -0.000106
# platelets_isNoestimate                   0.000000
# segmented_neutrophils                    0.001099
# lymphocytes                              0.000778
# monocytes                                0.000798
# eosinophils                             -0.000969
# basophils                                0.000142
# band_neutrophils                        -0.000504
# cholesterol                             -0.008756
# cholesterol_isMissing                   -0.000001
# urine_albumin_isNegative                -0.013149
# urine_albumin_is>=30                    -0.000580
# urine_albumin_is>=100                   -0.003566
# urine_albumin_is>=300                   -0.001201
# urine_albumin_is>=1000                  -0.000005
# urine_albumin_isTrace                   -0.001676
# urine_albumin_isBlankbutapplicable      -0.000003
# urine_glucose_isNegative                -0.011278
# urine_glucose_isLight                    0.000014
# urine_glucose_isMedium                  -0.001171
# urine_glucose_isDark                    -0.005337
# urine_glucose_isVerydark                -0.002919
# urine_glucose_isTrace                   -0.000019
# urine_glucose_isBlankbutapplicable       0.000067
# urine_pH                                -0.003704
# urine_pH_isBlankbutapplicable           -0.000029
# urine_hematest_isNegative                0.000811
# urine_hematest_isSmall                   0.000032
# urine_hematest_isModerate               -0.000031
# urine_hematest_isLarge                  -0.000028
# urine_hematest_isBlankbutapplicable      0.000027
# sedimentation_rate                      -0.016083
# sedimentation_rate_isBlankbutapplicable -0.001237
# uric_acid                               -0.022612
# uric_acid_isUnacceptable                 0.000202
# uric_acid_isTestnotdone                  0.000009
# systolic_blood_pressure                 -0.104860
# pulse_pressure                          -0.005231
# bmi                                     -0.042351
# $\displaystyle \mathcal{E}^*_{ij} = \frac{\mathrm{median}_t \left( I_{ij}(\Delta^{t}) \right)}{\sum_{v=1}^{n} \sum_{u > v}^{n} \left| \mathrm{median}_t \left( I_{uv}(\Delta^{t}) \right) \right|}$
#                                          sex_isFemale       age  \
# sex_isFemale                                 0.000000  1.000000
# age                                          0.999979  0.000000
# physical_activity                           -0.101094  0.511696
# serum_albumin                               -0.000867  0.167644
# alkaline_phosphatase                        -0.011105 -0.201740
# alkaline_phosphatase_isUnacceptable          0.000355 -0.000110
# alkaline_phosphatase_isTestnotdone          -0.000364  0.000506
# SGOT                                        -0.001203 -0.093136
# SGOT_isUnacceptable                          0.000000 -0.000693
# SGOT_isTestnotdone                          -0.000185  0.000000
# BUN                                         -0.000810  0.014245
# BUN_isUnacceptable                          -0.000027 -0.000005
# BUN_isTestnotdone                            0.000000  0.000000
# calcium                                     -0.004286  0.000852
# calcium_isUnacceptable                       0.000050  0.000346
# calcium_isTestnotdone                        0.000000  0.000113
# creatinine                                  -0.000082  0.000230
# creatinine_isUnacceptable                    0.000045  0.000000
# creatinine_isTestnotdone                     0.000000  0.000000
# potassium                                   -0.001071  0.025624
# potassium_isUnacceptable                     0.000000  0.000000
# sodium                                      -0.000980  0.010102
# sodium_isUnacceptable                       -0.000003  0.000000
# total_bilirubin                              0.006497  0.008442
# total_bilirubin_isUnacceptable              -0.000406  0.000046
# total_bilirubin_isTestnotdone               -0.000656 -0.000007
# serum_protein                               -0.001278 -0.237867
# red_blood_cells                              0.014365  0.033322
# red_blood_cells_isUnacceptable               0.000000  0.008233
# red_blood_cells_isBlankbutapplicable        -0.001398 -0.000075
# white_blood_cells                            0.047869 -0.026930
# white_blood_cells_isUnacceptable             0.000000  0.000470
# white_blood_cells_isBlankbutapplicable       0.000000  0.000000
# hemoglobin                                  -0.026634 -0.026667
# hemoglobin_isMissing                         0.000000  0.000000
# hematocrit                                  -0.056395  0.065696
# hematocrit_isUnacceptable                    0.000447  0.001243
# hematocrit_isMissing                         0.000000 -0.000001
# platelets_isNormal                           0.000000  0.000158
# platelets_isIncreased                        0.000195 -0.000222
# platelets_isDecreased                        0.000000  0.000003
# platelets_isNoestimate                       0.000000  0.000000
# segmented_neutrophils                        0.001201 -0.001329
# lymphocytes                                 -0.003123 -0.000825
# monocytes                                   -0.000483 -0.001492
# eosinophils                                 -0.000123  0.001025
# basophils                                    0.000000 -0.001144
# band_neutrophils                             0.000691 -0.000208
# cholesterol                                  0.000194 -0.088048
# cholesterol_isMissing                        0.000047  0.000000
# urine_albumin_isNegative                     0.000566  0.001781
# urine_albumin_is>=30                         0.000000 -0.000085
# urine_albumin_is>=100                       -0.000781 -0.004615
# urine_albumin_is>=300                        0.000853 -0.000759
# urine_albumin_is>=1000                       0.000000  0.000000
# urine_albumin_isTrace                       -0.000203 -0.001671
# urine_albumin_isBlankbutapplicable           0.000000  0.000199
# urine_glucose_isNegative                    -0.017602  0.075199
# urine_glucose_isLight                       -0.000115  0.000000
# urine_glucose_isMedium                      -0.001127  0.000033
# urine_glucose_isDark                        -0.010958 -0.002906
# urine_glucose_isVerydark                    -0.001371  0.007246
# urine_glucose_isTrace                        0.000000  0.000000
# urine_glucose_isBlankbutapplicable           0.000000 -0.000920
# urine_pH                                     0.000085 -0.001100
# urine_pH_isBlankbutapplicable                0.000000  0.000000
# urine_hematest_isNegative                    0.002247  0.000757
# urine_hematest_isSmall                       0.000000 -0.000425
# urine_hematest_isModerate                    0.000000 -0.000052
# urine_hematest_isLarge                       0.000000  0.000173
# urine_hematest_isBlankbutapplicable          0.000000  0.000000
# sedimentation_rate                          -0.270468  0.044321
# sedimentation_rate_isBlankbutapplicable      0.000000  0.001233
# uric_acid                                   -0.014899  0.008241
# uric_acid_isUnacceptable                    -0.000097 -0.000236
# uric_acid_isTestnotdone                      0.000000  0.000014
# systolic_blood_pressure                     -0.033557 -0.704008
# pulse_pressure                              -0.002769  0.036611
# bmi                                         -0.026253 -0.024007
#
#                                          physical_activity  serum_albumin  \
# sex_isFemale                                 -1.010934e-01  -8.675152e-04
# age                                           5.116979e-01   1.676468e-01
# physical_activity                             0.000000e+00   5.926008e-02
# serum_albumin                                 5.926028e-02   0.000000e+00
# alkaline_phosphatase                         -4.952509e-02  -1.481110e-03
# alkaline_phosphatase_isUnacceptable           0.000000e+00   0.000000e+00
# alkaline_phosphatase_isTestnotdone            0.000000e+00  -2.510928e-05
# SGOT                                         -1.824832e-03   2.248110e-03
# SGOT_isUnacceptable                           1.827167e-04  -1.267915e-04
# SGOT_isTestnotdone                            0.000000e+00  -5.768908e-05
# BUN                                          -6.417392e-04   9.452294e-04
# BUN_isUnacceptable                            0.000000e+00   0.000000e+00
# BUN_isTestnotdone                             0.000000e+00   0.000000e+00
# calcium                                      -1.585412e-04  -3.118946e-04
# calcium_isUnacceptable                        0.000000e+00  -9.950329e-05
# calcium_isTestnotdone                         0.000000e+00   6.422579e-05
# creatinine                                   -1.178165e-03   6.308446e-05
# creatinine_isUnacceptable                     0.000000e+00   0.000000e+00
# creatinine_isTestnotdone                      0.000000e+00   0.000000e+00
# potassium                                    -1.672776e-03   3.223896e-03
# potassium_isUnacceptable                     -5.187867e-07   0.000000e+00
# sodium                                       -1.700583e-04   7.714359e-04
# sodium_isUnacceptable                         0.000000e+00  -1.037573e-07
# total_bilirubin                              -7.255232e-04  -1.015006e-03
# total_bilirubin_isUnacceptable               -1.750386e-04   0.000000e+00
# total_bilirubin_isTestnotdone                -2.199656e-05   0.000000e+00
# serum_protein                                -7.549384e-04  -2.179738e-01
# red_blood_cells                              -1.863446e-02  -1.174844e-02
# red_blood_cells_isUnacceptable                2.776547e-03  -3.222496e-03
# red_blood_cells_isBlankbutapplicable          0.000000e+00   3.652259e-05
# white_blood_cells                            -2.250263e-02  -1.765003e-02
# white_blood_cells_isUnacceptable              0.000000e+00  -8.881629e-05
# white_blood_cells_isBlankbutapplicable        5.999250e-04   0.000000e+00
# hemoglobin                                   -4.359624e-04  -1.643273e-02
# hemoglobin_isMissing                          0.000000e+00   0.000000e+00
# hematocrit                                   -1.388937e-02   1.293813e-02
# hematocrit_isUnacceptable                     4.310080e-04  -3.318160e-04
# hematocrit_isMissing                          0.000000e+00   0.000000e+00
# platelets_isNormal                            0.000000e+00  -4.461566e-05
# platelets_isIncreased                        -1.552210e-04  -9.338161e-07
# platelets_isDecreased                         0.000000e+00  -5.447261e-05
# platelets_isNoestimate                        0.000000e+00   0.000000e+00
# segmented_neutrophils                        -7.162473e-03  -6.629576e-04
# lymphocytes                                  -6.212938e-03  -7.953357e-04
# monocytes                                    -3.966124e-04  -9.394709e-04
# eosinophils                                  -5.727302e-03  -6.183322e-04
# basophils                                     0.000000e+00   2.118466e-04
# band_neutrophils                              5.084110e-05   6.178750e-05
# cholesterol                                   4.365232e-02   1.672179e-02
# cholesterol_isMissing                         0.000000e+00   0.000000e+00
# urine_albumin_isNegative                      1.650831e-03   6.728353e-03
# urine_albumin_is>=30                         -9.119752e-04   1.958939e-04
# urine_albumin_is>=100                        -2.115612e-04  -1.200888e-03
# urine_albumin_is>=300                        -1.576074e-04   2.537386e-04
# urine_albumin_is>=1000                        0.000000e+00   0.000000e+00
# urine_albumin_isTrace                         1.354422e-03   2.579615e-03
# urine_albumin_isBlankbutapplicable            0.000000e+00  -3.579628e-04
# urine_glucose_isNegative                     -3.500047e-03  -6.714138e-03
# urine_glucose_isLight                         0.000000e+00   0.000000e+00
# urine_glucose_isMedium                       -6.671597e-04  -2.798699e-03
# urine_glucose_isDark                         -6.031414e-04  -8.744928e-04
# urine_glucose_isVerydark                     -1.917436e-04  -2.015071e-03
# urine_glucose_isTrace                        -1.218111e-04   0.000000e+00
# urine_glucose_isBlankbutapplicable            0.000000e+00   0.000000e+00
# urine_pH                                      1.866283e-03   6.244208e-03
# urine_pH_isBlankbutapplicable                 4.326681e-05   0.000000e+00
# urine_hematest_isNegative                    -1.034461e-04   2.661376e-04
# urine_hematest_isSmall                        0.000000e+00   0.000000e+00
# urine_hematest_isModerate                    -2.386419e-05   7.864807e-05
# urine_hematest_isLarge                        0.000000e+00   0.000000e+00
# urine_hematest_isBlankbutapplicable           0.000000e+00   0.000000e+00
# sedimentation_rate                            3.237707e-02  -2.201176e-02
# sedimentation_rate_isBlankbutapplicable      -3.216478e-05   1.254426e-04
# uric_acid                                     4.456586e-03   2.439081e-02
# uric_acid_isUnacceptable                     -1.028235e-04  -1.411100e-05
# uric_acid_isTestnotdone                       0.000000e+00   5.789660e-05
# systolic_blood_pressure                      -5.289031e-03  -3.402888e-02
# pulse_pressure                               -3.928461e-03  -2.837737e-03
# bmi                                          -1.159784e-02  -4.234597e-03
#
#                                          alkaline_phosphatase  \
# sex_isFemale                                    -1.110488e-02
# age                                             -2.017405e-01
# physical_activity                               -4.952560e-02
# serum_albumin                                   -1.480964e-03
# alkaline_phosphatase                             0.000000e+00
# alkaline_phosphatase_isUnacceptable              0.000000e+00
# alkaline_phosphatase_isTestnotdone               0.000000e+00
# SGOT                                            -1.477756e-01
# SGOT_isUnacceptable                              8.300588e-07
# SGOT_isTestnotdone                               0.000000e+00
# BUN                                             -4.218851e-02
# BUN_isUnacceptable                               1.933778e-04
# BUN_isTestnotdone                                0.000000e+00
# calcium                                         -2.450578e-02
# calcium_isUnacceptable                           3.134743e-03
# calcium_isTestnotdone                            0.000000e+00
# creatinine                                       8.561926e-04
# creatinine_isUnacceptable                        0.000000e+00
# creatinine_isTestnotdone                         0.000000e+00
# potassium                                       -2.505716e-02
# potassium_isUnacceptable                         0.000000e+00
# sodium                                          -7.220558e-03
# sodium_isUnacceptable                            0.000000e+00
# total_bilirubin                                 -5.000849e-02
# total_bilirubin_isUnacceptable                  -4.937715e-04
# total_bilirubin_isTestnotdone                    0.000000e+00
# serum_protein                                    2.863826e-03
# red_blood_cells                                 -3.449937e-03
# red_blood_cells_isUnacceptable                  -1.298834e-03
# red_blood_cells_isBlankbutapplicable             4.515649e-04
# white_blood_cells                               -1.075163e-03
# white_blood_cells_isUnacceptable                 4.035253e-04
# white_blood_cells_isBlankbutapplicable          -5.333776e-06
# hemoglobin                                       2.414317e-03
# hemoglobin_isMissing                             0.000000e+00
# hematocrit                                      -4.840571e-03
# hematocrit_isUnacceptable                       -1.331207e-04
# hematocrit_isMissing                            -3.112720e-07
# platelets_isNormal                              -1.256670e-03
# platelets_isIncreased                           -2.022101e-03
# platelets_isDecreased                            5.628836e-06
# platelets_isNoestimate                           0.000000e+00
# segmented_neutrophils                            4.017707e-03
# lymphocytes                                     -5.443564e-03
# monocytes                                        4.262806e-03
# eosinophils                                     -3.542159e-03
# basophils                                       -4.580887e-05
# band_neutrophils                                -2.452203e-03
# cholesterol                                      2.097463e-02
# cholesterol_isMissing                            0.000000e+00
# urine_albumin_isNegative                         9.063723e-04
# urine_albumin_is>=30                             9.587179e-05
# urine_albumin_is>=100                           -5.447266e-03
# urine_albumin_is>=300                           -1.466869e-04
# urine_albumin_is>=1000                           0.000000e+00
# urine_albumin_isTrace                           -9.673103e-05
# urine_albumin_isBlankbutapplicable               4.388936e-05
# urine_glucose_isNegative                        -3.798025e-03
# urine_glucose_isLight                            0.000000e+00
# urine_glucose_isMedium                          -8.425680e-04
# urine_glucose_isDark                            -3.693891e-04
# urine_glucose_isVerydark                        -1.607461e-04
# urine_glucose_isTrace                            0.000000e+00
# urine_glucose_isBlankbutapplicable               0.000000e+00
# urine_pH                                         2.857763e-03
# urine_pH_isBlankbutapplicable                    4.329275e-05
# urine_hematest_isNegative                        1.215777e-04
# urine_hematest_isSmall                           0.000000e+00
# urine_hematest_isModerate                        0.000000e+00
# urine_hematest_isLarge                           1.543391e-06
# urine_hematest_isBlankbutapplicable              0.000000e+00
# sedimentation_rate                              -1.258929e-02
# sedimentation_rate_isBlankbutapplicable          2.659560e-04
# uric_acid                                       -8.884527e-02
# uric_acid_isUnacceptable                        -6.699644e-07
# uric_acid_isTestnotdone                          0.000000e+00
# systolic_blood_pressure                          2.868154e-02
# pulse_pressure                                   3.935905e-04
# bmi                                              5.874686e-03
#
#                                          alkaline_phosphatase_isUnacceptable  \
# sex_isFemale                                                        0.000355
# age                                                                -0.000110
# physical_activity                                                   0.000000
# serum_albumin                                                       0.000000
# alkaline_phosphatase                                                0.000000
# alkaline_phosphatase_isUnacceptable                                 0.000000
# alkaline_phosphatase_isTestnotdone                                  0.000000
# SGOT                                                                0.000000
# SGOT_isUnacceptable                                                 0.000000
# SGOT_isTestnotdone                                                  0.000000
# BUN                                                                 0.000000
# BUN_isUnacceptable                                                  0.000000
# BUN_isTestnotdone                                                   0.000000
# calcium                                                             0.000000
# calcium_isUnacceptable                                              0.000000
# calcium_isTestnotdone                                               0.000000
# creatinine                                                          0.000000
# creatinine_isUnacceptable                                           0.000000
# creatinine_isTestnotdone                                            0.000000
# potassium                                                           0.000000
# potassium_isUnacceptable                                            0.000000
# sodium                                                              0.000000
# sodium_isUnacceptable                                               0.000000
# total_bilirubin                                                     0.000000
# total_bilirubin_isUnacceptable                                      0.000000
# total_bilirubin_isTestnotdone                                       0.000000
# serum_protein                                                       0.000000
# red_blood_cells                                                    -0.000005
# red_blood_cells_isUnacceptable                                      0.000000
# red_blood_cells_isBlankbutapplicable                                0.000000
# white_blood_cells                                                   0.000000
# white_blood_cells_isUnacceptable                                    0.000000
# white_blood_cells_isBlankbutapplicable                              0.000000
# hemoglobin                                                          0.000000
# hemoglobin_isMissing                                                0.000000
# hematocrit                                                          0.000000
# hematocrit_isUnacceptable                                           0.000000
# hematocrit_isMissing                                                0.000000
# platelets_isNormal                                                  0.000000
# platelets_isIncreased                                               0.000000
# platelets_isDecreased                                               0.000000
# platelets_isNoestimate                                              0.000000
# segmented_neutrophils                                               0.000000
# lymphocytes                                                         0.000000
# monocytes                                                           0.000000
# eosinophils                                                         0.000000
# basophils                                                           0.000000
# band_neutrophils                                                    0.000000
# cholesterol                                                         0.000000
# cholesterol_isMissing                                               0.000000
# urine_albumin_isNegative                                            0.000000
# urine_albumin_is>=30                                                0.000000
# urine_albumin_is>=100                                               0.000000
# urine_albumin_is>=300                                               0.000000
# urine_albumin_is>=1000                                              0.000000
# urine_albumin_isTrace                                               0.000000
# urine_albumin_isBlankbutapplicable                                  0.000000
# urine_glucose_isNegative                                            0.000000
# urine_glucose_isLight                                               0.000000
# urine_glucose_isMedium                                              0.000000
# urine_glucose_isDark                                               -0.000187
# urine_glucose_isVerydark                                            0.000000
# urine_glucose_isTrace                                               0.000000
# urine_glucose_isBlankbutapplicable                                  0.000000
# urine_pH                                                            0.000000
# urine_pH_isBlankbutapplicable                                       0.000000
# urine_hematest_isNegative                                           0.000000
# urine_hematest_isSmall                                              0.000000
# urine_hematest_isModerate                                           0.000000
# urine_hematest_isLarge                                              0.000000
# urine_hematest_isBlankbutapplicable                                 0.000000
# sedimentation_rate                                                  0.000034
# sedimentation_rate_isBlankbutapplicable                             0.000000
# uric_acid                                                           0.000000
# uric_acid_isUnacceptable                                            0.000000
# uric_acid_isTestnotdone                                             0.000000
# systolic_blood_pressure                                             0.000313
# pulse_pressure                                                      0.000000
# bmi                                                                 0.000000
#
#                                          alkaline_phosphatase_isTestnotdone  \
# sex_isFemale                                                  -3.645123e-04
# age                                                            5.118968e-04
# physical_activity                                              0.000000e+00
# serum_albumin                                                 -2.510730e-05
# alkaline_phosphatase                                           0.000000e+00
# alkaline_phosphatase_isUnacceptable                            0.000000e+00
# alkaline_phosphatase_isTestnotdone                             0.000000e+00
# SGOT                                                          -4.677187e-07
# SGOT_isUnacceptable                                            0.000000e+00
# SGOT_isTestnotdone                                             0.000000e+00
# BUN                                                            0.000000e+00
# BUN_isUnacceptable                                             0.000000e+00
# BUN_isTestnotdone                                              0.000000e+00
# calcium                                                        0.000000e+00
# calcium_isUnacceptable                                         0.000000e+00
# calcium_isTestnotdone                                          0.000000e+00
# creatinine                                                     0.000000e+00
# creatinine_isUnacceptable                                      0.000000e+00
# creatinine_isTestnotdone                                       0.000000e+00
# potassium                                                      0.000000e+00
# potassium_isUnacceptable                                       0.000000e+00
# sodium                                                         0.000000e+00
# sodium_isUnacceptable                                          0.000000e+00
# total_bilirubin                                                0.000000e+00
# total_bilirubin_isUnacceptable                                 0.000000e+00
# total_bilirubin_isTestnotdone                                  0.000000e+00
# serum_protein                                                 -2.220752e-06
# red_blood_cells                                                8.796292e-05
# red_blood_cells_isUnacceptable                                 3.044534e-04
# red_blood_cells_isBlankbutapplicable                           0.000000e+00
# white_blood_cells                                              7.418448e-06
# white_blood_cells_isUnacceptable                               0.000000e+00
# white_blood_cells_isBlankbutapplicable                         0.000000e+00
# hemoglobin                                                     8.604200e-05
# hemoglobin_isMissing                                           0.000000e+00
# hematocrit                                                     1.667687e-05
# hematocrit_isUnacceptable                                      0.000000e+00
# hematocrit_isMissing                                           0.000000e+00
# platelets_isNormal                                             0.000000e+00
# platelets_isIncreased                                          0.000000e+00
# platelets_isDecreased                                          0.000000e+00
# platelets_isNoestimate                                         0.000000e+00
# segmented_neutrophils                                          0.000000e+00
# lymphocytes                                                    0.000000e+00
# monocytes                                                      0.000000e+00
# eosinophils                                                    0.000000e+00
# basophils                                                      0.000000e+00
# band_neutrophils                                               0.000000e+00
# cholesterol                                                   -5.906539e-04
# cholesterol_isMissing                                          0.000000e+00
# urine_albumin_isNegative                                       0.000000e+00
# urine_albumin_is>=30                                           0.000000e+00
# urine_albumin_is>=100                                          0.000000e+00
# urine_albumin_is>=300                                          0.000000e+00
# urine_albumin_is>=1000                                         0.000000e+00
# urine_albumin_isTrace                                         -2.221056e-07
# urine_albumin_isBlankbutapplicable                             0.000000e+00
# urine_glucose_isNegative                                       0.000000e+00
# urine_glucose_isLight                                          0.000000e+00
# urine_glucose_isMedium                                         0.000000e+00
# urine_glucose_isDark                                           0.000000e+00
# urine_glucose_isVerydark                                       0.000000e+00
# urine_glucose_isTrace                                          0.000000e+00
# urine_glucose_isBlankbutapplicable                             0.000000e+00
# urine_pH                                                       0.000000e+00
# urine_pH_isBlankbutapplicable                                  0.000000e+00
# urine_hematest_isNegative                                      0.000000e+00
# urine_hematest_isSmall                                         0.000000e+00
# urine_hematest_isModerate                                      0.000000e+00
# urine_hematest_isLarge                                         0.000000e+00
# urine_hematest_isBlankbutapplicable                            0.000000e+00
# sedimentation_rate                                             7.531649e-05
# sedimentation_rate_isBlankbutapplicable                        0.000000e+00
# uric_acid                                                      0.000000e+00
# uric_acid_isUnacceptable                                       0.000000e+00
# uric_acid_isTestnotdone                                        0.000000e+00
# systolic_blood_pressure                                       -2.373776e-04
# pulse_pressure                                                -3.308177e-05
# bmi                                                            5.417258e-05
#
#                                                  SGOT  SGOT_isUnacceptable  \
# sex_isFemale                            -1.202165e-03         0.000000e+00
# age                                     -9.312669e-02        -6.928234e-04
# physical_activity                       -1.825000e-03         1.828002e-04
# serum_albumin                            2.247896e-03        -1.268190e-04
# alkaline_phosphatase                    -1.477755e-01         8.487027e-07
# alkaline_phosphatase_isUnacceptable      0.000000e+00         0.000000e+00
# alkaline_phosphatase_isTestnotdone      -4.669080e-07         0.000000e+00
# SGOT                                     0.000000e+00         2.721199e-05
# SGOT_isUnacceptable                      2.721036e-05         0.000000e+00
# SGOT_isTestnotdone                       0.000000e+00         0.000000e+00
# BUN                                     -7.410447e-03        -1.166460e-06
# BUN_isUnacceptable                       0.000000e+00         0.000000e+00
# BUN_isTestnotdone                       -4.669080e-07         0.000000e+00
# calcium                                 -2.152096e-03        -3.572479e-04
# calcium_isUnacceptable                  -4.244453e-04         0.000000e+00
# calcium_isTestnotdone                    0.000000e+00         0.000000e+00
# creatinine                              -1.207073e-03         0.000000e+00
# creatinine_isUnacceptable                0.000000e+00         0.000000e+00
# creatinine_isTestnotdone                 0.000000e+00         0.000000e+00
# potassium                               -1.588367e-02         0.000000e+00
# potassium_isUnacceptable                 0.000000e+00         0.000000e+00
# sodium                                  -8.415016e-03         0.000000e+00
# sodium_isUnacceptable                    0.000000e+00         0.000000e+00
# total_bilirubin                         -1.280979e-02        -8.166765e-04
# total_bilirubin_isUnacceptable           0.000000e+00         0.000000e+00
# total_bilirubin_isTestnotdone            0.000000e+00         0.000000e+00
# serum_protein                            1.710905e-03         3.072758e-05
# red_blood_cells                         -7.657039e-03        -5.111670e-04
# red_blood_cells_isUnacceptable          -2.116390e-04         0.000000e+00
# red_blood_cells_isBlankbutapplicable     0.000000e+00         0.000000e+00
# white_blood_cells                        9.248970e-04         3.505450e-04
# white_blood_cells_isUnacceptable         1.021102e-04         0.000000e+00
# white_blood_cells_isBlankbutapplicable   0.000000e+00         0.000000e+00
# hemoglobin                              -6.247197e-04         8.872712e-05
# hemoglobin_isMissing                     0.000000e+00         0.000000e+00
# hematocrit                               6.456787e-04        -6.600998e-04
# hematocrit_isUnacceptable               -3.864961e-06         0.000000e+00
# hematocrit_isMissing                     0.000000e+00         0.000000e+00
# platelets_isNormal                       0.000000e+00         7.207731e-05
# platelets_isIncreased                   -9.335567e-05         0.000000e+00
# platelets_isDecreased                    6.754603e-05        -3.455606e-06
# platelets_isNoestimate                   0.000000e+00         0.000000e+00
# segmented_neutrophils                   -5.922045e-02         1.226217e-04
# lymphocytes                             -8.633804e-03         5.437858e-05
# monocytes                                1.198979e-03         0.000000e+00
# eosinophils                             -5.510776e-03         1.270468e-04
# basophils                                4.951819e-05         0.000000e+00
# band_neutrophils                        -2.647109e-05         9.138104e-04
# cholesterol                              1.508677e-03         1.040046e-04
# cholesterol_isMissing                    0.000000e+00         0.000000e+00
# urine_albumin_isNegative                 3.206556e-03         2.563062e-04
# urine_albumin_is>=30                    -1.609795e-04         0.000000e+00
# urine_albumin_is>=100                   -1.669974e-03        -3.749045e-06
# urine_albumin_is>=300                   -5.844132e-05         0.000000e+00
# urine_albumin_is>=1000                   0.000000e+00         0.000000e+00
# urine_albumin_isTrace                   -1.182313e-03         1.595942e-04
# urine_albumin_isBlankbutapplicable       0.000000e+00         0.000000e+00
# urine_glucose_isNegative                 1.659599e-04         0.000000e+00
# urine_glucose_isLight                    0.000000e+00         0.000000e+00
# urine_glucose_isMedium                  -9.317410e-05         0.000000e+00
# urine_glucose_isDark                    -1.177646e-03        -1.104124e-05
# urine_glucose_isVerydark                 4.758377e-04        -5.504003e-07
# urine_glucose_isTrace                    0.000000e+00         0.000000e+00
# urine_glucose_isBlankbutapplicable       0.000000e+00         0.000000e+00
# urine_pH                                -1.695071e-04         0.000000e+00
# urine_pH_isBlankbutapplicable           -1.110204e-05         0.000000e+00
# urine_hematest_isNegative               -3.968718e-06         0.000000e+00
# urine_hematest_isSmall                   0.000000e+00         0.000000e+00
# urine_hematest_isModerate                0.000000e+00         0.000000e+00
# urine_hematest_isLarge                   0.000000e+00         0.000000e+00
# urine_hematest_isBlankbutapplicable      0.000000e+00         0.000000e+00
# sedimentation_rate                      -1.179220e-02        -4.671512e-05
# sedimentation_rate_isBlankbutapplicable  8.692271e-05         0.000000e+00
# uric_acid                               -8.081956e-03         0.000000e+00
# uric_acid_isUnacceptable                 0.000000e+00         0.000000e+00
# uric_acid_isTestnotdone                  0.000000e+00         0.000000e+00
# systolic_blood_pressure                 -8.371217e-03         1.590914e-03
# pulse_pressure                           2.195101e-03         5.056256e-04
# bmi                                      1.814577e-03         1.458950e-04
#
#                                          SGOT_isTestnotdone           BUN  \
# sex_isFemale                                      -0.000185 -8.097774e-04
# age                                                0.000000  1.423905e-02
# physical_activity                                  0.000000 -6.417943e-04
# serum_albumin                                     -0.000058  9.452684e-04
# alkaline_phosphatase                               0.000000 -4.218853e-02
# alkaline_phosphatase_isUnacceptable                0.000000  0.000000e+00
# alkaline_phosphatase_isTestnotdone                 0.000000  0.000000e+00
# SGOT                                               0.000000 -7.410476e-03
# SGOT_isUnacceptable                                0.000000 -1.167270e-06
# SGOT_isTestnotdone                                 0.000000  0.000000e+00
# BUN                                                0.000000  0.000000e+00
# BUN_isUnacceptable                                 0.000000  0.000000e+00
# BUN_isTestnotdone                                  0.000000  0.000000e+00
# calcium                                            0.000000 -1.222373e-02
# calcium_isUnacceptable                             0.000000  0.000000e+00
# calcium_isTestnotdone                              0.000000  0.000000e+00
# creatinine                                         0.000000  1.774173e-03
# creatinine_isUnacceptable                          0.000000  0.000000e+00
# creatinine_isTestnotdone                           0.000000  0.000000e+00
# potassium                                         -0.000007 -5.784410e-03
# potassium_isUnacceptable                           0.000000  0.000000e+00
# sodium                                             0.000000 -6.083890e-03
# sodium_isUnacceptable                              0.000000  0.000000e+00
# total_bilirubin                                    0.000014 -4.111346e-03
# total_bilirubin_isUnacceptable                     0.000000  0.000000e+00
# total_bilirubin_isTestnotdone                      0.000000  0.000000e+00
# serum_protein                                      0.000000  1.223105e-04
# red_blood_cells                                    0.000156 -1.899162e-03
# red_blood_cells_isUnacceptable                     0.000000 -2.308770e-03
# red_blood_cells_isBlankbutapplicable               0.000000 -2.120541e-06
# white_blood_cells                                 -0.000024 -1.476856e-04
# white_blood_cells_isUnacceptable                   0.000000  0.000000e+00
# white_blood_cells_isBlankbutapplicable             0.000000 -9.727251e-08
# hemoglobin                                        -0.000501  1.105061e-03
# hemoglobin_isMissing                               0.000000  0.000000e+00
# hematocrit                                         0.000000 -4.139147e-03
# hematocrit_isUnacceptable                          0.000000 -2.717145e-06
# hematocrit_isMissing                               0.000000  0.000000e+00
# platelets_isNormal                                 0.000000  0.000000e+00
# platelets_isIncreased                              0.000000  2.088117e-06
# platelets_isDecreased                              0.000000 -1.426664e-07
# platelets_isNoestimate                             0.000000  0.000000e+00
# segmented_neutrophils                              0.000000  4.653517e-05
# lymphocytes                                        0.000096  1.187535e-04
# monocytes                                          0.000000 -2.672621e-03
# eosinophils                                        0.000000  2.576814e-04
# basophils                                          0.000000  0.000000e+00
# band_neutrophils                                   0.000000  3.170435e-05
# cholesterol                                        0.000000  1.860820e-03
# cholesterol_isMissing                              0.000000  0.000000e+00
# urine_albumin_isNegative                           0.000000 -1.968030e-03
# urine_albumin_is>=30                               0.000000 -1.416936e-05
# urine_albumin_is>=100                              0.000000 -7.377439e-04
# urine_albumin_is>=300                              0.000000 -1.623802e-05
# urine_albumin_is>=1000                             0.000000  0.000000e+00
# urine_albumin_isTrace                              0.000000 -4.287124e-04
# urine_albumin_isBlankbutapplicable                 0.000000  0.000000e+00
# urine_glucose_isNegative                           0.000000  9.435433e-06
# urine_glucose_isLight                              0.000000  0.000000e+00
# urine_glucose_isMedium                             0.000000 -1.482433e-05
# urine_glucose_isDark                               0.000000  3.005072e-05
# urine_glucose_isVerydark                           0.000000 -3.487414e-04
# urine_glucose_isTrace                              0.000000  0.000000e+00
# urine_glucose_isBlankbutapplicable                 0.000000  0.000000e+00
# urine_pH                                           0.000000  1.086048e-04
# urine_pH_isBlankbutapplicable                      0.000000  0.000000e+00
# urine_hematest_isNegative                          0.000000  3.455119e-05
# urine_hematest_isSmall                             0.000000  0.000000e+00
# urine_hematest_isModerate                          0.000000  1.945450e-06
# urine_hematest_isLarge                             0.000000  0.000000e+00
# urine_hematest_isBlankbutapplicable                0.000000  0.000000e+00
# sedimentation_rate                                 0.000000  3.690227e-04
# sedimentation_rate_isBlankbutapplicable            0.000000 -1.234712e-05
# uric_acid                                          0.000000  1.358025e-02
# uric_acid_isUnacceptable                           0.000000 -3.047872e-07
# uric_acid_isTestnotdone                            0.000000  0.000000e+00
# systolic_blood_pressure                            0.000000 -5.732950e-04
# pulse_pressure                                    -0.000223  2.481201e-03
# bmi                                               -0.000009  8.416666e-04
#
#                                          BUN_isUnacceptable  \
# sex_isFemale                                  -2.723635e-05
# age                                           -4.879863e-06
# physical_activity                              0.000000e+00
# serum_albumin                                  0.000000e+00
# alkaline_phosphatase                           1.933804e-04
# alkaline_phosphatase_isUnacceptable            0.000000e+00
# alkaline_phosphatase_isTestnotdone             0.000000e+00
# SGOT                                           0.000000e+00
# SGOT_isUnacceptable                            0.000000e+00
# SGOT_isTestnotdone                             0.000000e+00
# BUN                                            0.000000e+00
# BUN_isUnacceptable                             0.000000e+00
# BUN_isTestnotdone                              0.000000e+00
# calcium                                        0.000000e+00
# calcium_isUnacceptable                         0.000000e+00
# calcium_isTestnotdone                          0.000000e+00
# creatinine                                     0.000000e+00
# creatinine_isUnacceptable                      0.000000e+00
# creatinine_isTestnotdone                       0.000000e+00
# potassium                                      0.000000e+00
# potassium_isUnacceptable                       0.000000e+00
# sodium                                        -1.121167e-06
# sodium_isUnacceptable                          0.000000e+00
# total_bilirubin                                0.000000e+00
# total_bilirubin_isUnacceptable                 0.000000e+00
# total_bilirubin_isTestnotdone                  0.000000e+00
# serum_protein                                  0.000000e+00
# ...
# SGOT_isTestnotdone                                      0.000000
# BUN                                                     0.000000
# BUN_isUnacceptable                                      0.000000
# BUN_isTestnotdone                                       0.000000
# calcium                                                 0.000000
# calcium_isUnacceptable                                  0.000000
# calcium_isTestnotdone                                   0.000000
# creatinine                                              0.000000
# creatinine_isUnacceptable                               0.000000
# creatinine_isTestnotdone                                0.000000
# potassium                                               0.000000
# potassium_isUnacceptable                                0.000000
# sodium                                                  0.000000
# sodium_isUnacceptable                                   0.000000
# total_bilirubin                                         0.000000
# total_bilirubin_isUnacceptable                          0.000000
# total_bilirubin_isTestnotdone                           0.000000
# serum_protein                                          -0.000021
# red_blood_cells                                         0.000000
# red_blood_cells_isUnacceptable                          0.000000
# red_blood_cells_isBlankbutapplicable                    0.000000
# white_blood_cells                                       0.000000
# white_blood_cells_isUnacceptable                        0.000000
# white_blood_cells_isBlankbutapplicable                  0.000000
# hemoglobin                                              0.000000
# hemoglobin_isMissing                                    0.000000
# hematocrit                                              0.000000
# hematocrit_isUnacceptable                               0.000000
# hematocrit_isMissing                                    0.000000
# platelets_isNormal                                      0.000000
# platelets_isIncreased                                   0.000000
# platelets_isDecreased                                   0.000000
# platelets_isNoestimate                                  0.000000
# segmented_neutrophils                                   0.000030
# lymphocytes                                             0.000000
# monocytes                                               0.000000
# eosinophils                                             0.000000
# basophils                                               0.000000
# band_neutrophils                                        0.000000
# cholesterol                                            -0.000022
# cholesterol_isMissing                                   0.000000
# urine_albumin_isNegative                                0.000000
# urine_albumin_is>=30                                    0.000000
# urine_albumin_is>=100                                   0.000000
# urine_albumin_is>=300                                   0.000000
# urine_albumin_is>=1000                                  0.000000
# urine_albumin_isTrace                                   0.000000
# urine_albumin_isBlankbutapplicable                      0.000000
# urine_glucose_isNegative                                0.000000
# urine_glucose_isLight                                   0.000000
# urine_glucose_isMedium                                  0.000000
# urine_glucose_isDark                                    0.000000
# urine_glucose_isVerydark                                0.000000
# urine_glucose_isTrace                                   0.000000
# urine_glucose_isBlankbutapplicable                      0.000000
# urine_pH                                                0.000088
# urine_pH_isBlankbutapplicable                           0.000000
# urine_hematest_isNegative                               0.000000
# urine_hematest_isSmall                                  0.000000
# urine_hematest_isModerate                               0.000000
# urine_hematest_isLarge                                  0.000000
# urine_hematest_isBlankbutapplicable                     0.000000
# sedimentation_rate                                      0.000000
# sedimentation_rate_isBlankbutapplicable                 0.000000
# uric_acid                                               0.000000
# uric_acid_isUnacceptable                                0.000000
# uric_acid_isTestnotdone                                 0.000000
# systolic_blood_pressure                                -0.000027
# pulse_pressure                                         -0.000008
# bmi                                                     0.000000
#
#                                          systolic_blood_pressure  \
# sex_isFemale                                       -3.355864e-02
# age                                                -7.039897e-01
# physical_activity                                  -5.290380e-03
# serum_albumin                                      -3.402938e-02
# alkaline_phosphatase                                2.868190e-02
# alkaline_phosphatase_isUnacceptable                 3.128900e-04
# alkaline_phosphatase_isTestnotdone                 -2.373968e-04
# SGOT                                               -8.371247e-03
# SGOT_isUnacceptable                                 1.590704e-03
# SGOT_isTestnotdone                                  0.000000e+00
# BUN                                                -5.735706e-04
# BUN_isUnacceptable                                 -2.282662e-06
# BUN_isTestnotdone                                  -6.100932e-05
# calcium                                            -1.086132e-03
# calcium_isUnacceptable                              7.100115e-04
# calcium_isTestnotdone                               0.000000e+00
# creatinine                                         -1.015784e-04
# creatinine_isUnacceptable                           0.000000e+00
# creatinine_isTestnotdone                            0.000000e+00
# potassium                                           5.896685e-03
# potassium_isUnacceptable                            6.889488e-05
# sodium                                             -2.587708e-04
# sodium_isUnacceptable                               0.000000e+00
# total_bilirubin                                     1.295255e-03
# total_bilirubin_isUnacceptable                      3.357588e-04
# total_bilirubin_isTestnotdone                      -1.087377e-04
# serum_protein                                      -1.351367e-02
# red_blood_cells                                    -1.001017e-02
# red_blood_cells_isUnacceptable                     -1.338055e-03
# red_blood_cells_isBlankbutapplicable                1.361296e-04
# white_blood_cells                                  -2.650522e-02
# white_blood_cells_isUnacceptable                    0.000000e+00
# white_blood_cells_isBlankbutapplicable              4.025785e-05
# hemoglobin                                          7.242522e-04
# hemoglobin_isMissing                                0.000000e+00
# hematocrit                                         -2.027584e-02
# hematocrit_isUnacceptable                          -6.556167e-06
# hematocrit_isMissing                                0.000000e+00
# platelets_isNormal                                  7.200760e-05
# platelets_isIncreased                              -1.628990e-05
# platelets_isDecreased                               3.942779e-06
# platelets_isNoestimate                              0.000000e+00
# segmented_neutrophils                               3.911652e-04
# lymphocytes                                        -8.804848e-04
# monocytes                                           1.824054e-03
# eosinophils                                        -8.970082e-04
# basophils                                          -1.768025e-04
# band_neutrophils                                   -3.011038e-04
# cholesterol                                        -2.045693e-02
# cholesterol_isMissing                               0.000000e+00
# urine_albumin_isNegative                            7.779726e-04
# urine_albumin_is>=30                               -1.243013e-04
# urine_albumin_is>=100                              -2.094135e-03
# urine_albumin_is>=300                               1.533534e-04
# urine_albumin_is>=1000                              0.000000e+00
# urine_albumin_isTrace                              -1.046082e-03
# urine_albumin_isBlankbutapplicable                  4.399312e-05
# urine_glucose_isNegative                            1.493556e-02
# urine_glucose_isLight                               0.000000e+00
# urine_glucose_isMedium                              1.272584e-04
# urine_glucose_isDark                                3.721880e-03
# urine_glucose_isVerydark                            4.952027e-03
# urine_glucose_isTrace                              -1.245088e-06
# urine_glucose_isBlankbutapplicable                  0.000000e+00
# urine_pH                                            2.700933e-03
# urine_pH_isBlankbutapplicable                       0.000000e+00
# urine_hematest_isNegative                          -1.556360e-04
# urine_hematest_isSmall                              2.780697e-05
# urine_hematest_isModerate                          -8.300588e-07
# urine_hematest_isLarge                             -3.320235e-06
# urine_hematest_isBlankbutapplicable                 0.000000e+00
# sedimentation_rate                                 -2.782889e-02
# sedimentation_rate_isBlankbutapplicable             1.311493e-04
# uric_acid                                           1.953669e-02
# uric_acid_isUnacceptable                            2.739194e-05
# uric_acid_isTestnotdone                            -2.656188e-05
# systolic_blood_pressure                             0.000000e+00
# pulse_pressure                                     -1.642711e-01
# bmi                                                -1.823997e-02
#
#                                          pulse_pressure           bmi
# sex_isFemale                              -2.769595e-03 -2.625185e-02
# age                                        3.662510e-02 -2.401526e-02
# physical_activity                         -3.928461e-03 -1.159836e-02
# serum_albumin                             -2.837861e-03 -4.234735e-03
# alkaline_phosphatase                       3.935840e-04  5.874119e-03
# alkaline_phosphatase_isUnacceptable        0.000000e+00  0.000000e+00
# alkaline_phosphatase_isTestnotdone        -3.309859e-05  5.416133e-05
# SGOT                                       2.195003e-03  1.815079e-03
# SGOT_isUnacceptable                        5.056355e-04  1.459347e-04
# SGOT_isTestnotdone                        -2.228189e-04 -8.715617e-06
# BUN                                        2.481279e-03  8.416277e-04
# BUN_isUnacceptable                         0.000000e+00  0.000000e+00
# BUN_isTestnotdone                          0.000000e+00 -2.075147e-07
# calcium                                    1.976658e-03 -4.947669e-04
# calcium_isUnacceptable                    -7.444589e-06  5.089428e-04
# calcium_isTestnotdone                      0.000000e+00 -3.112720e-06
# creatinine                                -6.071361e-04  9.045566e-04
# creatinine_isUnacceptable                  0.000000e+00  0.000000e+00
# creatinine_isTestnotdone                   0.000000e+00  0.000000e+00
# potassium                                 -7.104071e-03 -1.358339e-03
# potassium_isUnacceptable                  -7.641728e-05 -1.037573e-05
# sodium                                    -9.890669e-05  9.971599e-04
# sodium_isUnacceptable                      0.000000e+00  0.000000e+00
# total_bilirubin                           -2.397168e-03 -3.374448e-03
# total_bilirubin_isUnacceptable             0.000000e+00  1.031244e-03
# total_bilirubin_isTestnotdone             -8.028224e-06 -9.026889e-06
# serum_protein                              4.734432e-03  3.789737e-05
# red_blood_cells                           -6.361908e-03 -3.376829e-02
# red_blood_cells_isUnacceptable            -4.889721e-03  2.925957e-05
# red_blood_cells_isBlankbutapplicable       0.000000e+00  2.773434e-04
# white_blood_cells                         -2.297146e-03  8.778598e-03
# white_blood_cells_isUnacceptable          -5.628836e-06  0.000000e+00
# white_blood_cells_isBlankbutapplicable     0.000000e+00  3.110645e-04
# hemoglobin                                -3.291825e-03 -7.517375e-03
# hemoglobin_isMissing                       0.000000e+00  0.000000e+00
# hematocrit                                -1.800605e-03 -7.265763e-03
# hematocrit_isUnacceptable                 -4.974841e-04 -3.199877e-04
# hematocrit_isMissing                       0.000000e+00 -2.075147e-05
# platelets_isNormal                         0.000000e+00  1.449490e-04
# platelets_isIncreased                     -7.833680e-06 -4.606826e-05
# platelets_isDecreased                     -1.069998e-05 -1.075445e-04
# platelets_isNoestimate                     0.000000e+00  0.000000e+00
# segmented_neutrophils                     -2.578649e-03  1.275048e-04
# lymphocytes                               -6.759532e-04  2.293582e-03
# monocytes                                 -3.176791e-04 -1.211315e-03
# eosinophils                                6.591891e-04 -3.533310e-03
# basophils                                  6.497804e-05  1.736898e-04
# band_neutrophils                          -1.826932e-04  1.220705e-04
# cholesterol                               -2.366498e-03 -2.890680e-04
# cholesterol_isMissing                      0.000000e+00  0.000000e+00
# urine_albumin_isNegative                  -5.251548e-04 -3.730699e-03
# urine_albumin_is>=30                      -4.060284e-04 -2.075666e-04
# urine_albumin_is>=100                     -3.943817e-04 -3.504508e-03
# urine_albumin_is>=300                     -4.279991e-07 -5.153524e-03
# urine_albumin_is>=1000                    -1.621209e-07  0.000000e+00
# urine_albumin_isTrace                     -7.996254e-04  7.092333e-04
# urine_albumin_isBlankbutapplicable        -1.245737e-04  0.000000e+00
# urine_glucose_isNegative                  -4.768428e-04 -2.580367e-03
# urine_glucose_isLight                      0.000000e+00 -4.420063e-05
# urine_glucose_isMedium                    -3.190538e-06 -9.072543e-04
# urine_glucose_isDark                      -7.775802e-04 -6.691830e-04
# urine_glucose_isVerydark                  -1.497074e-03 -1.073681e-03
# urine_glucose_isTrace                     -2.593934e-07 -3.828646e-05
# urine_glucose_isBlankbutapplicable         0.000000e+00  0.000000e+00
# urine_pH                                   1.891723e-03  6.012323e-03
# urine_pH_isBlankbutapplicable              9.906232e-05  0.000000e+00
# urine_hematest_isNegative                 -1.291455e-05 -5.645437e-04
# urine_hematest_isSmall                     1.920548e-04 -6.619719e-05
# urine_hematest_isModerate                  1.395536e-05  8.902380e-05
# urine_hematest_isLarge                     0.000000e+00 -5.042607e-05
# urine_hematest_isBlankbutapplicable        0.000000e+00  0.000000e+00
# sedimentation_rate                        -9.834653e-03 -2.208475e-04
# sedimentation_rate_isBlankbutapplicable   -2.440814e-03  2.699092e-03
# uric_acid                                 -8.560500e-04 -1.563774e-02
# uric_acid_isUnacceptable                   4.028379e-05  6.650846e-05
# uric_acid_isTestnotdone                   -7.522408e-06  0.000000e+00
# systolic_blood_pressure                   -1.642709e-01 -1.823893e-02
# pulse_pressure                             0.000000e+00 -3.947967e-04
# bmi                                       -3.946629e-04  0.000000e+00

# %% [markdown]
# ## Visualization

# %%
shap_cmap = shap.plots.colors.red_blue
positive_color = shap_cmap(0.0)[:3]
negative_color = shap_cmap(1.0)[:3]

positive_alpha = 0.01
negative_alpha = 0.01
positive_beta = 0
negative_beta = 0

# %%
positive_color
# Out:
# (np.float64(0.0),
#  np.float64(0.5433775692459107),
#  np.float64(0.983379062301401))

# %%
draw(
    psi=psi_2,
    r=r_2,
    psi_q25=psi_1_median,
    psi_q75=psi_1_median,
    r_q25=r_1_q_lower,
    r_q75=r_1_q_upper,
    positive_alpha=positive_alpha,
    negative_alpha=negative_alpha,
    positive_beta=positive_beta,
    negative_beta=negative_beta,
    negative_color=negative_color,
    positive_color=positive_color,
    uncertain_color='grey',
    output_path=os.path.join('..', '..', 'result', 'nhanesi_xgboost_iqr_gamma_15_network.jpg')
)
# Out:
# Saving the graph to ..\..\result\nhanesi_xgboost_iqr_gamma_15_network.jpg

# %% [markdown]
# ## Experimenting with γ
#
# To explore different tolerance levels, modify the `gamma` parameter above and re-run the notebook:
#
# - **γ = 10**: Very permissive (40th-60th percentiles) → fewer gray nodes, more confident classifications
# - **γ = 25**: Classical IQR (25th-75th percentiles) → balanced approach
# - **γ = 35**: Stricter (15th-85th percentiles) → more gray nodes, highlighting heterogeneity
# - **γ = 45**: Very strict (5th-95th percentiles) → maximum gray nodes, only very consistent effects classified
#
# The parameter γ can be adjusted according to specific requirements:
# - Use **smaller γ** when you want to emphasize dominant patterns
# - Use **larger γ** when you want to be conservative and highlight patient heterogeneity

# %%
# Tolerance parameter for percentile-based uncertainty
gamma = 25  # Classical IQR when γ = 25

# Compute percentile bounds
lower_percentile = 50 - gamma  # e.g., 25th percentile when γ = 25
upper_percentile = 50 + gamma  # e.g., 75th percentile when γ = 25

print(f"Using γ = {gamma}")
print(f"Computing {lower_percentile}th and {upper_percentile}th percentiles")
print(f"This means at least {upper_percentile}% of patients must agree on sign for consistent classification")
# Out:
# Using γ = 25
# Computing 25th and 75th percentiles
# This means at least 75% of patients must agree on sign for consistent classification

# %% [markdown]
# ## Build Median-Based SHAP Values (psi_1)

# %%
shap_values_clean = np.nan_to_num(shap_values)
n_features = shap_values_clean.shape[1]

# Calculate median SHAP values across patients
median_shap = np.median(shap_values_clean, axis=0)

# Calculate percentiles using γ parameter
# When γ = 25, this gives classical IQR (25th to 75th percentile)
q_lower_shap = np.percentile(shap_values_clean, lower_percentile, axis=0)
q_upper_shap = np.percentile(shap_values_clean, upper_percentile, axis=0)
iqr_shap = q_upper_shap - q_lower_shap

# Calculate absolute median for normalization
sum_abs_median_shap = np.sum(np.abs(median_shap))

# Build psi matrices
psi_1_median = pd.DataFrame()
psi_1_median['value'] = median_shap / sum_abs_median_shap
psi_1_median['iqr'] = iqr_shap / sum_abs_median_shap
psi_1_median[f'q25'] = q_lower_shap / sum_abs_median_shap
psi_1_median[f'q75'] = q_upper_shap / sum_abs_median_shap
psi_1_median['cv'] = iqr_shap / (np.abs(median_shap) + 1e-10)  # Coefficient of variation
psi_1_median.set_index(X_shapley.columns, inplace=True)

print(f"Median-based node weights (psi) with uncertainty (γ = {gamma}):")
print(psi_1_median.head(10))
# Out:
# Median-based node weights (psi) with uncertainty (γ = 25):
#                                         value       iqr       q25       q75  \
# sex_isFemale                        -0.116573  0.288061 -0.145974  0.142087
# age                                 -0.569398  1.702762 -1.063666  0.639096
# physical_activity                   -0.029324  0.082411 -0.036644  0.045767
# serum_albumin                       -0.032719  0.079724 -0.039339  0.040386
# alkaline_phosphatase                -0.000573  0.006678 -0.002890  0.003787
# alkaline_phosphatase_isUnacceptable -0.000006  0.000576 -0.000016  0.000560
# alkaline_phosphatase_isTestnotdone  -0.000050  0.000068 -0.000106 -0.000038
# SGOT                                -0.002691  0.004986 -0.004954  0.000032
# SGOT_isUnacceptable                 -0.000293  0.000125 -0.000355 -0.000230
# SGOT_isTestnotdone                  -0.000036  0.000014 -0.000041 -0.000027
#
#                                             cv
# sex_isFemale                          2.471069
# age                                   2.990459
# physical_activity                     2.810377
# serum_albumin                         2.436602
# alkaline_phosphatase                 11.649275
# alkaline_phosphatase_isUnacceptable  93.108467
# alkaline_phosphatase_isTestnotdone    1.352256
# SGOT                                  1.853132
# SGOT_isUnacceptable                   0.425102
# SGOT_isTestnotdone                    0.393075

# %% [markdown]
# ## Build Median-Based Interaction Values (r_1)

# %%
# Remove diagonal
n_variables = shap_interaction_values.shape[1]
filtered_shap_interaction_values = np.nan_to_num(shap_interaction_values.copy())
idx_patients = np.repeat(np.arange(num_patients), n_variables)
idx_variables = np.tile(np.arange(n_variables), num_patients)
filtered_shap_interaction_values[idx_patients, idx_variables, idx_variables] = 0

# Calculate median interaction values across patients
median_interaction = np.median(filtered_shap_interaction_values, axis=0)

# Calculate percentiles using γ parameter for interactions
q_lower_interaction = np.percentile(filtered_shap_interaction_values, lower_percentile, axis=0)
q_upper_interaction = np.percentile(filtered_shap_interaction_values, upper_percentile, axis=0)
iqr_interaction = q_upper_interaction - q_lower_interaction

# Normalize
sum_abs_median_interaction = np.sum(np.abs(median_interaction))

# Build r_1 with uncertainty
r_1_median = pd.DataFrame(median_interaction / sum_abs_median_interaction)
r_1_median.rename(columns=dict(list(zip(r_1_median.columns, X_shapley.columns))), inplace=True)
r_1_median.set_index(X_shapley.columns, inplace=True)

# Store IQR separately
r_1_iqr = pd.DataFrame(iqr_interaction / sum_abs_median_interaction)
r_1_iqr.rename(columns=dict(list(zip(r_1_iqr.columns, X_shapley.columns))), inplace=True)
r_1_iqr.set_index(X_shapley.columns, inplace=True)

print(f"\nMedian-based edge weights (r) computed with γ = {gamma}")
print(f"Mean IQR for interactions: {iqr_interaction.mean():.6f}")
# Out:
# Median-based edge weights (r) computed with γ = 25
# Mean IQR for interactions: 0.000146

# %%
# Store lower and upper percentiles for interactions
r_1_q_lower = pd.DataFrame(q_lower_interaction / sum_abs_median_interaction)
r_1_q_lower.rename(columns=dict(list(zip(r_1_q_lower.columns, X_shapley.columns))), inplace=True)
r_1_q_lower.set_index(X_shapley.columns, inplace=True)

r_1_q_upper = pd.DataFrame(q_upper_interaction / sum_abs_median_interaction)
r_1_q_upper.rename(columns=dict(list(zip(r_1_q_upper.columns, X_shapley.columns))), inplace=True)
r_1_q_upper.set_index(X_shapley.columns, inplace=True)

print(f"Lower ({lower_percentile}th) and upper ({upper_percentile}th) percentile dataframes created for interactions")
# Out:
# Lower (25th) and upper (75th) percentile dataframes created for interactions

# %% [markdown]
# ## Normalize Matrices

# %%
from IPython.display import display, Math

# Create psi_1 with just the value column for normalization
psi_1 = psi_1_median[['value']].copy()
psi_2 = normalize_psi(psi_1)
r_2 = normalize_r(r_1_median)

display(Math(r"\mathcal{N}^*_i = \frac{\mathrm{median}_t \left( Sh_{i}(\Delta^{t}) \right)}{\sum_{u=1}^{n} \left| \mathrm{median}_t \left( Sh_{u}(\Delta^{t}) \right) \right|}"))
display(psi_2)
display(Math(r"\mathcal{E}^*_{ij} = \frac{\mathrm{median}_t \left( I_{ij}(\Delta^{t}) \right)}{\sum_{v=1}^{n} \sum_{u > v}^{n} \left| \mathrm{median}_t \left( I_{uv}(\Delta^{t}) \right) \right|}"))
display(r_2)
# Out:
# $\displaystyle \mathcal{N}^*_i = \frac{\mathrm{median}_t \left( Sh_{i}(\Delta^{t}) \right)}{\sum_{u=1}^{n} \left| \mathrm{median}_t \left( Sh_{u}(\Delta^{t}) \right) \right|}$
#                                             value
# sex_isFemale                            -0.204731
# age                                     -1.000000
# physical_activity                       -0.051500
# serum_albumin                           -0.057463
# alkaline_phosphatase                    -0.001007
# alkaline_phosphatase_isUnacceptable     -0.000011
# alkaline_phosphatase_isTestnotdone      -0.000088
# SGOT                                    -0.004726
# SGOT_isUnacceptable                     -0.000515
# SGOT_isTestnotdone                      -0.000064
# BUN                                      0.003906
# BUN_isUnacceptable                      -0.000024
# BUN_isTestnotdone                       -0.000012
# calcium                                  0.001390
# calcium_isUnacceptable                  -0.000716
# calcium_isTestnotdone                   -0.000026
# creatinine                              -0.000099
# creatinine_isUnacceptable                0.000050
# creatinine_isTestnotdone                 0.000000
# potassium                                0.006528
# potassium_isUnacceptable                -0.000030
# sodium                                   0.001450
# sodium_isUnacceptable                   -0.000005
# total_bilirubin                          0.001156
# total_bilirubin_isUnacceptable          -0.000213
# total_bilirubin_isTestnotdone           -0.000015
# serum_protein                           -0.014350
# red_blood_cells                         -0.045425
# red_blood_cells_isUnacceptable          -0.006847
# red_blood_cells_isBlankbutapplicable    -0.000224
# white_blood_cells                       -0.061665
# white_blood_cells_isUnacceptable         0.000003
# white_blood_cells_isBlankbutapplicable  -0.000054
# hemoglobin                              -0.002763
# hemoglobin_isMissing                     0.000000
# hematocrit                              -0.036389
# hematocrit_isUnacceptable               -0.000558
# hematocrit_isMissing                    -0.000009
# platelets_isNormal                       0.000138
# platelets_isIncreased                   -0.000708
# platelets_isDecreased                   -0.000106
# platelets_isNoestimate                   0.000000
# segmented_neutrophils                    0.001099
# lymphocytes                              0.000778
# monocytes                                0.000798
# eosinophils                             -0.000969
# basophils                                0.000142
# band_neutrophils                        -0.000504
# cholesterol                             -0.008756
# cholesterol_isMissing                   -0.000001
# urine_albumin_isNegative                -0.013149
# urine_albumin_is>=30                    -0.000580
# urine_albumin_is>=100                   -0.003566
# urine_albumin_is>=300                   -0.001201
# urine_albumin_is>=1000                  -0.000005
# urine_albumin_isTrace                   -0.001676
# urine_albumin_isBlankbutapplicable      -0.000003
# urine_glucose_isNegative                -0.011278
# urine_glucose_isLight                    0.000014
# urine_glucose_isMedium                  -0.001171
# urine_glucose_isDark                    -0.005337
# urine_glucose_isVerydark                -0.002919
# urine_glucose_isTrace                   -0.000019
# urine_glucose_isBlankbutapplicable       0.000067
# urine_pH                                -0.003704
# urine_pH_isBlankbutapplicable           -0.000029
# urine_hematest_isNegative                0.000811
# urine_hematest_isSmall                   0.000032
# urine_hematest_isModerate               -0.000031
# urine_hematest_isLarge                  -0.000028
# urine_hematest_isBlankbutapplicable      0.000027
# sedimentation_rate                      -0.016083
# sedimentation_rate_isBlankbutapplicable -0.001237
# uric_acid                               -0.022612
# uric_acid_isUnacceptable                 0.000202
# uric_acid_isTestnotdone                  0.000009
# systolic_blood_pressure                 -0.104860
# pulse_pressure                          -0.005231
# bmi                                     -0.042351
# $\displaystyle \mathcal{E}^*_{ij} = \frac{\mathrm{median}_t \left( I_{ij}(\Delta^{t}) \right)}{\sum_{v=1}^{n} \sum_{u > v}^{n} \left| \mathrm{median}_t \left( I_{uv}(\Delta^{t}) \right) \right|}$
#                                          sex_isFemale       age  \
# sex_isFemale                                 0.000000  1.000000
# age                                          0.999979  0.000000
# physical_activity                           -0.101094  0.511696
# serum_albumin                               -0.000867  0.167644
# alkaline_phosphatase                        -0.011105 -0.201740
# alkaline_phosphatase_isUnacceptable          0.000355 -0.000110
# alkaline_phosphatase_isTestnotdone          -0.000364  0.000506
# SGOT                                        -0.001203 -0.093136
# SGOT_isUnacceptable                          0.000000 -0.000693
# SGOT_isTestnotdone                          -0.000185  0.000000
# BUN                                         -0.000810  0.014245
# BUN_isUnacceptable                          -0.000027 -0.000005
# BUN_isTestnotdone                            0.000000  0.000000
# calcium                                     -0.004286  0.000852
# calcium_isUnacceptable                       0.000050  0.000346
# calcium_isTestnotdone                        0.000000  0.000113
# creatinine                                  -0.000082  0.000230
# creatinine_isUnacceptable                    0.000045  0.000000
# creatinine_isTestnotdone                     0.000000  0.000000
# potassium                                   -0.001071  0.025624
# potassium_isUnacceptable                     0.000000  0.000000
# sodium                                      -0.000980  0.010102
# sodium_isUnacceptable                       -0.000003  0.000000
# total_bilirubin                              0.006497  0.008442
# total_bilirubin_isUnacceptable              -0.000406  0.000046
# total_bilirubin_isTestnotdone               -0.000656 -0.000007
# serum_protein                               -0.001278 -0.237867
# red_blood_cells                              0.014365  0.033322
# red_blood_cells_isUnacceptable               0.000000  0.008233
# red_blood_cells_isBlankbutapplicable        -0.001398 -0.000075
# white_blood_cells                            0.047869 -0.026930
# white_blood_cells_isUnacceptable             0.000000  0.000470
# white_blood_cells_isBlankbutapplicable       0.000000  0.000000
# hemoglobin                                  -0.026634 -0.026667
# hemoglobin_isMissing                         0.000000  0.000000
# hematocrit                                  -0.056395  0.065696
# hematocrit_isUnacceptable                    0.000447  0.001243
# hematocrit_isMissing                         0.000000 -0.000001
# platelets_isNormal                           0.000000  0.000158
# platelets_isIncreased                        0.000195 -0.000222
# platelets_isDecreased                        0.000000  0.000003
# platelets_isNoestimate                       0.000000  0.000000
# segmented_neutrophils                        0.001201 -0.001329
# lymphocytes                                 -0.003123 -0.000825
# monocytes                                   -0.000483 -0.001492
# eosinophils                                 -0.000123  0.001025
# basophils                                    0.000000 -0.001144
# band_neutrophils                             0.000691 -0.000208
# cholesterol                                  0.000194 -0.088048
# cholesterol_isMissing                        0.000047  0.000000
# urine_albumin_isNegative                     0.000566  0.001781
# urine_albumin_is>=30                         0.000000 -0.000085
# urine_albumin_is>=100                       -0.000781 -0.004615
# urine_albumin_is>=300                        0.000853 -0.000759
# urine_albumin_is>=1000                       0.000000  0.000000
# urine_albumin_isTrace                       -0.000203 -0.001671
# urine_albumin_isBlankbutapplicable           0.000000  0.000199
# urine_glucose_isNegative                    -0.017602  0.075199
# urine_glucose_isLight                       -0.000115  0.000000
# urine_glucose_isMedium                      -0.001127  0.000033
# urine_glucose_isDark                        -0.010958 -0.002906
# urine_glucose_isVerydark                    -0.001371  0.007246
# urine_glucose_isTrace                        0.000000  0.000000
# urine_glucose_isBlankbutapplicable           0.000000 -0.000920
# urine_pH                                     0.000085 -0.001100
# urine_pH_isBlankbutapplicable                0.000000  0.000000
# urine_hematest_isNegative                    0.002247  0.000757
# urine_hematest_isSmall                       0.000000 -0.000425
# urine_hematest_isModerate                    0.000000 -0.000052
# urine_hematest_isLarge                       0.000000  0.000173
# urine_hematest_isBlankbutapplicable          0.000000  0.000000
# sedimentation_rate                          -0.270468  0.044321
# sedimentation_rate_isBlankbutapplicable      0.000000  0.001233
# uric_acid                                   -0.014899  0.008241
# uric_acid_isUnacceptable                    -0.000097 -0.000236
# uric_acid_isTestnotdone                      0.000000  0.000014
# systolic_blood_pressure                     -0.033557 -0.704008
# pulse_pressure                              -0.002769  0.036611
# bmi                                         -0.026253 -0.024007
#
#                                          physical_activity  serum_albumin  \
# sex_isFemale                                 -1.010934e-01  -8.675152e-04
# age                                           5.116979e-01   1.676468e-01
# physical_activity                             0.000000e+00   5.926008e-02
# serum_albumin                                 5.926028e-02   0.000000e+00
# alkaline_phosphatase                         -4.952509e-02  -1.481110e-03
# alkaline_phosphatase_isUnacceptable           0.000000e+00   0.000000e+00
# alkaline_phosphatase_isTestnotdone            0.000000e+00  -2.510928e-05
# SGOT                                         -1.824832e-03   2.248110e-03
# SGOT_isUnacceptable                           1.827167e-04  -1.267915e-04
# SGOT_isTestnotdone                            0.000000e+00  -5.768908e-05
# BUN                                          -6.417392e-04   9.452294e-04
# BUN_isUnacceptable                            0.000000e+00   0.000000e+00
# BUN_isTestnotdone                             0.000000e+00   0.000000e+00
# calcium                                      -1.585412e-04  -3.118946e-04
# calcium_isUnacceptable                        0.000000e+00  -9.950329e-05
# calcium_isTestnotdone                         0.000000e+00   6.422579e-05
# creatinine                                   -1.178165e-03   6.308446e-05
# creatinine_isUnacceptable                     0.000000e+00   0.000000e+00
# creatinine_isTestnotdone                      0.000000e+00   0.000000e+00
# potassium                                    -1.672776e-03   3.223896e-03
# potassium_isUnacceptable                     -5.187867e-07   0.000000e+00
# sodium                                       -1.700583e-04   7.714359e-04
# sodium_isUnacceptable                         0.000000e+00  -1.037573e-07
# total_bilirubin                              -7.255232e-04  -1.015006e-03
# total_bilirubin_isUnacceptable               -1.750386e-04   0.000000e+00
# total_bilirubin_isTestnotdone                -2.199656e-05   0.000000e+00
# serum_protein                                -7.549384e-04  -2.179738e-01
# red_blood_cells                              -1.863446e-02  -1.174844e-02
# red_blood_cells_isUnacceptable                2.776547e-03  -3.222496e-03
# red_blood_cells_isBlankbutapplicable          0.000000e+00   3.652259e-05
# white_blood_cells                            -2.250263e-02  -1.765003e-02
# white_blood_cells_isUnacceptable              0.000000e+00  -8.881629e-05
# white_blood_cells_isBlankbutapplicable        5.999250e-04   0.000000e+00
# hemoglobin                                   -4.359624e-04  -1.643273e-02
# hemoglobin_isMissing                          0.000000e+00   0.000000e+00
# hematocrit                                   -1.388937e-02   1.293813e-02
# hematocrit_isUnacceptable                     4.310080e-04  -3.318160e-04
# hematocrit_isMissing                          0.000000e+00   0.000000e+00
# platelets_isNormal                            0.000000e+00  -4.461566e-05
# platelets_isIncreased                        -1.552210e-04  -9.338161e-07
# platelets_isDecreased                         0.000000e+00  -5.447261e-05
# platelets_isNoestimate                        0.000000e+00   0.000000e+00
# segmented_neutrophils                        -7.162473e-03  -6.629576e-04
# lymphocytes                                  -6.212938e-03  -7.953357e-04
# monocytes                                    -3.966124e-04  -9.394709e-04
# eosinophils                                  -5.727302e-03  -6.183322e-04
# basophils                                     0.000000e+00   2.118466e-04
# band_neutrophils                              5.084110e-05   6.178750e-05
# cholesterol                                   4.365232e-02   1.672179e-02
# cholesterol_isMissing                         0.000000e+00   0.000000e+00
# urine_albumin_isNegative                      1.650831e-03   6.728353e-03
# urine_albumin_is>=30                         -9.119752e-04   1.958939e-04
# urine_albumin_is>=100                        -2.115612e-04  -1.200888e-03
# urine_albumin_is>=300                        -1.576074e-04   2.537386e-04
# urine_albumin_is>=1000                        0.000000e+00   0.000000e+00
# urine_albumin_isTrace                         1.354422e-03   2.579615e-03
# urine_albumin_isBlankbutapplicable            0.000000e+00  -3.579628e-04
# urine_glucose_isNegative                     -3.500047e-03  -6.714138e-03
# urine_glucose_isLight                         0.000000e+00   0.000000e+00
# urine_glucose_isMedium                       -6.671597e-04  -2.798699e-03
# urine_glucose_isDark                         -6.031414e-04  -8.744928e-04
# urine_glucose_isVerydark                     -1.917436e-04  -2.015071e-03
# urine_glucose_isTrace                        -1.218111e-04   0.000000e+00
# urine_glucose_isBlankbutapplicable            0.000000e+00   0.000000e+00
# urine_pH                                      1.866283e-03   6.244208e-03
# urine_pH_isBlankbutapplicable                 4.326681e-05   0.000000e+00
# urine_hematest_isNegative                    -1.034461e-04   2.661376e-04
# urine_hematest_isSmall                        0.000000e+00   0.000000e+00
# urine_hematest_isModerate                    -2.386419e-05   7.864807e-05
# urine_hematest_isLarge                        0.000000e+00   0.000000e+00
# urine_hematest_isBlankbutapplicable           0.000000e+00   0.000000e+00
# sedimentation_rate                            3.237707e-02  -2.201176e-02
# sedimentation_rate_isBlankbutapplicable      -3.216478e-05   1.254426e-04
# uric_acid                                     4.456586e-03   2.439081e-02
# uric_acid_isUnacceptable                     -1.028235e-04  -1.411100e-05
# uric_acid_isTestnotdone                       0.000000e+00   5.789660e-05
# systolic_blood_pressure                      -5.289031e-03  -3.402888e-02
# pulse_pressure                               -3.928461e-03  -2.837737e-03
# bmi                                          -1.159784e-02  -4.234597e-03
#
#                                          alkaline_phosphatase  \
# sex_isFemale                                    -1.110488e-02
# age                                             -2.017405e-01
# physical_activity                               -4.952560e-02
# serum_albumin                                   -1.480964e-03
# alkaline_phosphatase                             0.000000e+00
# alkaline_phosphatase_isUnacceptable              0.000000e+00
# alkaline_phosphatase_isTestnotdone               0.000000e+00
# SGOT                                            -1.477756e-01
# SGOT_isUnacceptable                              8.300588e-07
# SGOT_isTestnotdone                               0.000000e+00
# BUN                                             -4.218851e-02
# BUN_isUnacceptable                               1.933778e-04
# BUN_isTestnotdone                                0.000000e+00
# calcium                                         -2.450578e-02
# calcium_isUnacceptable                           3.134743e-03
# calcium_isTestnotdone                            0.000000e+00
# creatinine                                       8.561926e-04
# creatinine_isUnacceptable                        0.000000e+00
# creatinine_isTestnotdone                         0.000000e+00
# potassium                                       -2.505716e-02
# potassium_isUnacceptable                         0.000000e+00
# sodium                                          -7.220558e-03
# sodium_isUnacceptable                            0.000000e+00
# total_bilirubin                                 -5.000849e-02
# total_bilirubin_isUnacceptable                  -4.937715e-04
# total_bilirubin_isTestnotdone                    0.000000e+00
# serum_protein                                    2.863826e-03
# red_blood_cells                                 -3.449937e-03
# red_blood_cells_isUnacceptable                  -1.298834e-03
# red_blood_cells_isBlankbutapplicable             4.515649e-04
# white_blood_cells                               -1.075163e-03
# white_blood_cells_isUnacceptable                 4.035253e-04
# white_blood_cells_isBlankbutapplicable          -5.333776e-06
# hemoglobin                                       2.414317e-03
# hemoglobin_isMissing                             0.000000e+00
# hematocrit                                      -4.840571e-03
# hematocrit_isUnacceptable                       -1.331207e-04
# hematocrit_isMissing                            -3.112720e-07
# platelets_isNormal                              -1.256670e-03
# platelets_isIncreased                           -2.022101e-03
# platelets_isDecreased                            5.628836e-06
# platelets_isNoestimate                           0.000000e+00
# segmented_neutrophils                            4.017707e-03
# lymphocytes                                     -5.443564e-03
# monocytes                                        4.262806e-03
# eosinophils                                     -3.542159e-03
# basophils                                       -4.580887e-05
# band_neutrophils                                -2.452203e-03
# cholesterol                                      2.097463e-02
# cholesterol_isMissing                            0.000000e+00
# urine_albumin_isNegative                         9.063723e-04
# urine_albumin_is>=30                             9.587179e-05
# urine_albumin_is>=100                           -5.447266e-03
# urine_albumin_is>=300                           -1.466869e-04
# urine_albumin_is>=1000                           0.000000e+00
# urine_albumin_isTrace                           -9.673103e-05
# urine_albumin_isBlankbutapplicable               4.388936e-05
# urine_glucose_isNegative                        -3.798025e-03
# urine_glucose_isLight                            0.000000e+00
# urine_glucose_isMedium                          -8.425680e-04
# urine_glucose_isDark                            -3.693891e-04
# urine_glucose_isVerydark                        -1.607461e-04
# urine_glucose_isTrace                            0.000000e+00
# urine_glucose_isBlankbutapplicable               0.000000e+00
# urine_pH                                         2.857763e-03
# urine_pH_isBlankbutapplicable                    4.329275e-05
# urine_hematest_isNegative                        1.215777e-04
# urine_hematest_isSmall                           0.000000e+00
# urine_hematest_isModerate                        0.000000e+00
# urine_hematest_isLarge                           1.543391e-06
# urine_hematest_isBlankbutapplicable              0.000000e+00
# sedimentation_rate                              -1.258929e-02
# sedimentation_rate_isBlankbutapplicable          2.659560e-04
# uric_acid                                       -8.884527e-02
# uric_acid_isUnacceptable                        -6.699644e-07
# uric_acid_isTestnotdone                          0.000000e+00
# systolic_blood_pressure                          2.868154e-02
# pulse_pressure                                   3.935905e-04
# bmi                                              5.874686e-03
#
#                                          alkaline_phosphatase_isUnacceptable  \
# sex_isFemale                                                        0.000355
# age                                                                -0.000110
# physical_activity                                                   0.000000
# serum_albumin                                                       0.000000
# alkaline_phosphatase                                                0.000000
# alkaline_phosphatase_isUnacceptable                                 0.000000
# alkaline_phosphatase_isTestnotdone                                  0.000000
# SGOT                                                                0.000000
# SGOT_isUnacceptable                                                 0.000000
# SGOT_isTestnotdone                                                  0.000000
# BUN                                                                 0.000000
# BUN_isUnacceptable                                                  0.000000
# BUN_isTestnotdone                                                   0.000000
# calcium                                                             0.000000
# calcium_isUnacceptable                                              0.000000
# calcium_isTestnotdone                                               0.000000
# creatinine                                                          0.000000
# creatinine_isUnacceptable                                           0.000000
# creatinine_isTestnotdone                                            0.000000
# potassium                                                           0.000000
# potassium_isUnacceptable                                            0.000000
# sodium                                                              0.000000
# sodium_isUnacceptable                                               0.000000
# total_bilirubin                                                     0.000000
# total_bilirubin_isUnacceptable                                      0.000000
# total_bilirubin_isTestnotdone                                       0.000000
# serum_protein                                                       0.000000
# red_blood_cells                                                    -0.000005
# red_blood_cells_isUnacceptable                                      0.000000
# red_blood_cells_isBlankbutapplicable                                0.000000
# white_blood_cells                                                   0.000000
# white_blood_cells_isUnacceptable                                    0.000000
# white_blood_cells_isBlankbutapplicable                              0.000000
# hemoglobin                                                          0.000000
# hemoglobin_isMissing                                                0.000000
# hematocrit                                                          0.000000
# hematocrit_isUnacceptable                                           0.000000
# hematocrit_isMissing                                                0.000000
# platelets_isNormal                                                  0.000000
# platelets_isIncreased                                               0.000000
# platelets_isDecreased                                               0.000000
# platelets_isNoestimate                                              0.000000
# segmented_neutrophils                                               0.000000
# lymphocytes                                                         0.000000
# monocytes                                                           0.000000
# eosinophils                                                         0.000000
# basophils                                                           0.000000
# band_neutrophils                                                    0.000000
# cholesterol                                                         0.000000
# cholesterol_isMissing                                               0.000000
# urine_albumin_isNegative                                            0.000000
# urine_albumin_is>=30                                                0.000000
# urine_albumin_is>=100                                               0.000000
# urine_albumin_is>=300                                               0.000000
# urine_albumin_is>=1000                                              0.000000
# urine_albumin_isTrace                                               0.000000
# urine_albumin_isBlankbutapplicable                                  0.000000
# urine_glucose_isNegative                                            0.000000
# urine_glucose_isLight                                               0.000000
# urine_glucose_isMedium                                              0.000000
# urine_glucose_isDark                                               -0.000187
# urine_glucose_isVerydark                                            0.000000
# urine_glucose_isTrace                                               0.000000
# urine_glucose_isBlankbutapplicable                                  0.000000
# urine_pH                                                            0.000000
# urine_pH_isBlankbutapplicable                                       0.000000
# urine_hematest_isNegative                                           0.000000
# urine_hematest_isSmall                                              0.000000
# urine_hematest_isModerate                                           0.000000
# urine_hematest_isLarge                                              0.000000
# urine_hematest_isBlankbutapplicable                                 0.000000
# sedimentation_rate                                                  0.000034
# sedimentation_rate_isBlankbutapplicable                             0.000000
# uric_acid                                                           0.000000
# uric_acid_isUnacceptable                                            0.000000
# uric_acid_isTestnotdone                                             0.000000
# systolic_blood_pressure                                             0.000313
# pulse_pressure                                                      0.000000
# bmi                                                                 0.000000
#
#                                          alkaline_phosphatase_isTestnotdone  \
# sex_isFemale                                                  -3.645123e-04
# age                                                            5.118968e-04
# physical_activity                                              0.000000e+00
# serum_albumin                                                 -2.510730e-05
# alkaline_phosphatase                                           0.000000e+00
# alkaline_phosphatase_isUnacceptable                            0.000000e+00
# alkaline_phosphatase_isTestnotdone                             0.000000e+00
# SGOT                                                          -4.677187e-07
# SGOT_isUnacceptable                                            0.000000e+00
# SGOT_isTestnotdone                                             0.000000e+00
# BUN                                                            0.000000e+00
# BUN_isUnacceptable                                             0.000000e+00
# BUN_isTestnotdone                                              0.000000e+00
# calcium                                                        0.000000e+00
# calcium_isUnacceptable                                         0.000000e+00
# calcium_isTestnotdone                                          0.000000e+00
# creatinine                                                     0.000000e+00
# creatinine_isUnacceptable                                      0.000000e+00
# creatinine_isTestnotdone                                       0.000000e+00
# potassium                                                      0.000000e+00
# potassium_isUnacceptable                                       0.000000e+00
# sodium                                                         0.000000e+00
# sodium_isUnacceptable                                          0.000000e+00
# total_bilirubin                                                0.000000e+00
# total_bilirubin_isUnacceptable                                 0.000000e+00
# total_bilirubin_isTestnotdone                                  0.000000e+00
# serum_protein                                                 -2.220752e-06
# red_blood_cells                                                8.796292e-05
# red_blood_cells_isUnacceptable                                 3.044534e-04
# red_blood_cells_isBlankbutapplicable                           0.000000e+00
# white_blood_cells                                              7.418448e-06
# white_blood_cells_isUnacceptable                               0.000000e+00
# white_blood_cells_isBlankbutapplicable                         0.000000e+00
# hemoglobin                                                     8.604200e-05
# hemoglobin_isMissing                                           0.000000e+00
# hematocrit                                                     1.667687e-05
# hematocrit_isUnacceptable                                      0.000000e+00
# hematocrit_isMissing                                           0.000000e+00
# platelets_isNormal                                             0.000000e+00
# platelets_isIncreased                                          0.000000e+00
# platelets_isDecreased                                          0.000000e+00
# platelets_isNoestimate                                         0.000000e+00
# segmented_neutrophils                                          0.000000e+00
# lymphocytes                                                    0.000000e+00
# monocytes                                                      0.000000e+00
# eosinophils                                                    0.000000e+00
# basophils                                                      0.000000e+00
# band_neutrophils                                               0.000000e+00
# cholesterol                                                   -5.906539e-04
# cholesterol_isMissing                                          0.000000e+00
# urine_albumin_isNegative                                       0.000000e+00
# urine_albumin_is>=30                                           0.000000e+00
# urine_albumin_is>=100                                          0.000000e+00
# urine_albumin_is>=300                                          0.000000e+00
# urine_albumin_is>=1000                                         0.000000e+00
# urine_albumin_isTrace                                         -2.221056e-07
# urine_albumin_isBlankbutapplicable                             0.000000e+00
# urine_glucose_isNegative                                       0.000000e+00
# urine_glucose_isLight                                          0.000000e+00
# urine_glucose_isMedium                                         0.000000e+00
# urine_glucose_isDark                                           0.000000e+00
# urine_glucose_isVerydark                                       0.000000e+00
# urine_glucose_isTrace                                          0.000000e+00
# urine_glucose_isBlankbutapplicable                             0.000000e+00
# urine_pH                                                       0.000000e+00
# urine_pH_isBlankbutapplicable                                  0.000000e+00
# urine_hematest_isNegative                                      0.000000e+00
# urine_hematest_isSmall                                         0.000000e+00
# urine_hematest_isModerate                                      0.000000e+00
# urine_hematest_isLarge                                         0.000000e+00
# urine_hematest_isBlankbutapplicable                            0.000000e+00
# sedimentation_rate                                             7.531649e-05
# sedimentation_rate_isBlankbutapplicable                        0.000000e+00
# uric_acid                                                      0.000000e+00
# uric_acid_isUnacceptable                                       0.000000e+00
# uric_acid_isTestnotdone                                        0.000000e+00
# systolic_blood_pressure                                       -2.373776e-04
# pulse_pressure                                                -3.308177e-05
# bmi                                                            5.417258e-05
#
#                                                  SGOT  SGOT_isUnacceptable  \
# sex_isFemale                            -1.202165e-03         0.000000e+00
# age                                     -9.312669e-02        -6.928234e-04
# physical_activity                       -1.825000e-03         1.828002e-04
# serum_albumin                            2.247896e-03        -1.268190e-04
# alkaline_phosphatase                    -1.477755e-01         8.487027e-07
# alkaline_phosphatase_isUnacceptable      0.000000e+00         0.000000e+00
# alkaline_phosphatase_isTestnotdone      -4.669080e-07         0.000000e+00
# SGOT                                     0.000000e+00         2.721199e-05
# SGOT_isUnacceptable                      2.721036e-05         0.000000e+00
# SGOT_isTestnotdone                       0.000000e+00         0.000000e+00
# BUN                                     -7.410447e-03        -1.166460e-06
# BUN_isUnacceptable                       0.000000e+00         0.000000e+00
# BUN_isTestnotdone                       -4.669080e-07         0.000000e+00
# calcium                                 -2.152096e-03        -3.572479e-04
# calcium_isUnacceptable                  -4.244453e-04         0.000000e+00
# calcium_isTestnotdone                    0.000000e+00         0.000000e+00
# creatinine                              -1.207073e-03         0.000000e+00
# creatinine_isUnacceptable                0.000000e+00         0.000000e+00
# creatinine_isTestnotdone                 0.000000e+00         0.000000e+00
# potassium                               -1.588367e-02         0.000000e+00
# potassium_isUnacceptable                 0.000000e+00         0.000000e+00
# sodium                                  -8.415016e-03         0.000000e+00
# sodium_isUnacceptable                    0.000000e+00         0.000000e+00
# total_bilirubin                         -1.280979e-02        -8.166765e-04
# total_bilirubin_isUnacceptable           0.000000e+00         0.000000e+00
# total_bilirubin_isTestnotdone            0.000000e+00         0.000000e+00
# serum_protein                            1.710905e-03         3.072758e-05
# red_blood_cells                         -7.657039e-03        -5.111670e-04
# red_blood_cells_isUnacceptable          -2.116390e-04         0.000000e+00
# red_blood_cells_isBlankbutapplicable     0.000000e+00         0.000000e+00
# white_blood_cells                        9.248970e-04         3.505450e-04
# white_blood_cells_isUnacceptable         1.021102e-04         0.000000e+00
# white_blood_cells_isBlankbutapplicable   0.000000e+00         0.000000e+00
# hemoglobin                              -6.247197e-04         8.872712e-05
# hemoglobin_isMissing                     0.000000e+00         0.000000e+00
# hematocrit                               6.456787e-04        -6.600998e-04
# hematocrit_isUnacceptable               -3.864961e-06         0.000000e+00
# hematocrit_isMissing                     0.000000e+00         0.000000e+00
# platelets_isNormal                       0.000000e+00         7.207731e-05
# platelets_isIncreased                   -9.335567e-05         0.000000e+00
# platelets_isDecreased                    6.754603e-05        -3.455606e-06
# platelets_isNoestimate                   0.000000e+00         0.000000e+00
# segmented_neutrophils                   -5.922045e-02         1.226217e-04
# lymphocytes                             -8.633804e-03         5.437858e-05
# monocytes                                1.198979e-03         0.000000e+00
# eosinophils                             -5.510776e-03         1.270468e-04
# basophils                                4.951819e-05         0.000000e+00
# band_neutrophils                        -2.647109e-05         9.138104e-04
# cholesterol                              1.508677e-03         1.040046e-04
# cholesterol_isMissing                    0.000000e+00         0.000000e+00
# urine_albumin_isNegative                 3.206556e-03         2.563062e-04
# urine_albumin_is>=30                    -1.609795e-04         0.000000e+00
# urine_albumin_is>=100                   -1.669974e-03        -3.749045e-06
# urine_albumin_is>=300                   -5.844132e-05         0.000000e+00
# urine_albumin_is>=1000                   0.000000e+00         0.000000e+00
# urine_albumin_isTrace                   -1.182313e-03         1.595942e-04
# urine_albumin_isBlankbutapplicable       0.000000e+00         0.000000e+00
# urine_glucose_isNegative                 1.659599e-04         0.000000e+00
# urine_glucose_isLight                    0.000000e+00         0.000000e+00
# urine_glucose_isMedium                  -9.317410e-05         0.000000e+00
# urine_glucose_isDark                    -1.177646e-03        -1.104124e-05
# urine_glucose_isVerydark                 4.758377e-04        -5.504003e-07
# urine_glucose_isTrace                    0.000000e+00         0.000000e+00
# urine_glucose_isBlankbutapplicable       0.000000e+00         0.000000e+00
# urine_pH                                -1.695071e-04         0.000000e+00
# urine_pH_isBlankbutapplicable           -1.110204e-05         0.000000e+00
# urine_hematest_isNegative               -3.968718e-06         0.000000e+00
# urine_hematest_isSmall                   0.000000e+00         0.000000e+00
# urine_hematest_isModerate                0.000000e+00         0.000000e+00
# urine_hematest_isLarge                   0.000000e+00         0.000000e+00
# urine_hematest_isBlankbutapplicable      0.000000e+00         0.000000e+00
# sedimentation_rate                      -1.179220e-02        -4.671512e-05
# sedimentation_rate_isBlankbutapplicable  8.692271e-05         0.000000e+00
# uric_acid                               -8.081956e-03         0.000000e+00
# uric_acid_isUnacceptable                 0.000000e+00         0.000000e+00
# uric_acid_isTestnotdone                  0.000000e+00         0.000000e+00
# systolic_blood_pressure                 -8.371217e-03         1.590914e-03
# pulse_pressure                           2.195101e-03         5.056256e-04
# bmi                                      1.814577e-03         1.458950e-04
#
#                                          SGOT_isTestnotdone           BUN  \
# sex_isFemale                                      -0.000185 -8.097774e-04
# age                                                0.000000  1.423905e-02
# physical_activity                                  0.000000 -6.417943e-04
# serum_albumin                                     -0.000058  9.452684e-04
# alkaline_phosphatase                               0.000000 -4.218853e-02
# alkaline_phosphatase_isUnacceptable                0.000000  0.000000e+00
# alkaline_phosphatase_isTestnotdone                 0.000000  0.000000e+00
# SGOT                                               0.000000 -7.410476e-03
# SGOT_isUnacceptable                                0.000000 -1.167270e-06
# SGOT_isTestnotdone                                 0.000000  0.000000e+00
# BUN                                                0.000000  0.000000e+00
# BUN_isUnacceptable                                 0.000000  0.000000e+00
# BUN_isTestnotdone                                  0.000000  0.000000e+00
# calcium                                            0.000000 -1.222373e-02
# calcium_isUnacceptable                             0.000000  0.000000e+00
# calcium_isTestnotdone                              0.000000  0.000000e+00
# creatinine                                         0.000000  1.774173e-03
# creatinine_isUnacceptable                          0.000000  0.000000e+00
# creatinine_isTestnotdone                           0.000000  0.000000e+00
# potassium                                         -0.000007 -5.784410e-03
# potassium_isUnacceptable                           0.000000  0.000000e+00
# sodium                                             0.000000 -6.083890e-03
# sodium_isUnacceptable                              0.000000  0.000000e+00
# total_bilirubin                                    0.000014 -4.111346e-03
# total_bilirubin_isUnacceptable                     0.000000  0.000000e+00
# total_bilirubin_isTestnotdone                      0.000000  0.000000e+00
# serum_protein                                      0.000000  1.223105e-04
# red_blood_cells                                    0.000156 -1.899162e-03
# red_blood_cells_isUnacceptable                     0.000000 -2.308770e-03
# red_blood_cells_isBlankbutapplicable               0.000000 -2.120541e-06
# white_blood_cells                                 -0.000024 -1.476856e-04
# white_blood_cells_isUnacceptable                   0.000000  0.000000e+00
# white_blood_cells_isBlankbutapplicable             0.000000 -9.727251e-08
# hemoglobin                                        -0.000501  1.105061e-03
# hemoglobin_isMissing                               0.000000  0.000000e+00
# hematocrit                                         0.000000 -4.139147e-03
# hematocrit_isUnacceptable                          0.000000 -2.717145e-06
# hematocrit_isMissing                               0.000000  0.000000e+00
# platelets_isNormal                                 0.000000  0.000000e+00
# platelets_isIncreased                              0.000000  2.088117e-06
# platelets_isDecreased                              0.000000 -1.426664e-07
# platelets_isNoestimate                             0.000000  0.000000e+00
# segmented_neutrophils                              0.000000  4.653517e-05
# lymphocytes                                        0.000096  1.187535e-04
# monocytes                                          0.000000 -2.672621e-03
# eosinophils                                        0.000000  2.576814e-04
# basophils                                          0.000000  0.000000e+00
# band_neutrophils                                   0.000000  3.170435e-05
# cholesterol                                        0.000000  1.860820e-03
# cholesterol_isMissing                              0.000000  0.000000e+00
# urine_albumin_isNegative                           0.000000 -1.968030e-03
# urine_albumin_is>=30                               0.000000 -1.416936e-05
# urine_albumin_is>=100                              0.000000 -7.377439e-04
# urine_albumin_is>=300                              0.000000 -1.623802e-05
# urine_albumin_is>=1000                             0.000000  0.000000e+00
# urine_albumin_isTrace                              0.000000 -4.287124e-04
# urine_albumin_isBlankbutapplicable                 0.000000  0.000000e+00
# urine_glucose_isNegative                           0.000000  9.435433e-06
# urine_glucose_isLight                              0.000000  0.000000e+00
# urine_glucose_isMedium                             0.000000 -1.482433e-05
# urine_glucose_isDark                               0.000000  3.005072e-05
# urine_glucose_isVerydark                           0.000000 -3.487414e-04
# urine_glucose_isTrace                              0.000000  0.000000e+00
# urine_glucose_isBlankbutapplicable                 0.000000  0.000000e+00
# urine_pH                                           0.000000  1.086048e-04
# urine_pH_isBlankbutapplicable                      0.000000  0.000000e+00
# urine_hematest_isNegative                          0.000000  3.455119e-05
# urine_hematest_isSmall                             0.000000  0.000000e+00
# urine_hematest_isModerate                          0.000000  1.945450e-06
# urine_hematest_isLarge                             0.000000  0.000000e+00
# urine_hematest_isBlankbutapplicable                0.000000  0.000000e+00
# sedimentation_rate                                 0.000000  3.690227e-04
# sedimentation_rate_isBlankbutapplicable            0.000000 -1.234712e-05
# uric_acid                                          0.000000  1.358025e-02
# uric_acid_isUnacceptable                           0.000000 -3.047872e-07
# uric_acid_isTestnotdone                            0.000000  0.000000e+00
# systolic_blood_pressure                            0.000000 -5.732950e-04
# pulse_pressure                                    -0.000223  2.481201e-03
# bmi                                               -0.000009  8.416666e-04
#
#                                          BUN_isUnacceptable  \
# sex_isFemale                                  -2.723635e-05
# age                                           -4.879863e-06
# physical_activity                              0.000000e+00
# serum_albumin                                  0.000000e+00
# alkaline_phosphatase                           1.933804e-04
# alkaline_phosphatase_isUnacceptable            0.000000e+00
# alkaline_phosphatase_isTestnotdone             0.000000e+00
# SGOT                                           0.000000e+00
# SGOT_isUnacceptable                            0.000000e+00
# SGOT_isTestnotdone                             0.000000e+00
# BUN                                            0.000000e+00
# BUN_isUnacceptable                             0.000000e+00
# BUN_isTestnotdone                              0.000000e+00
# calcium                                        0.000000e+00
# calcium_isUnacceptable                         0.000000e+00
# calcium_isTestnotdone                          0.000000e+00
# creatinine                                     0.000000e+00
# creatinine_isUnacceptable                      0.000000e+00
# creatinine_isTestnotdone                       0.000000e+00
# potassium                                      0.000000e+00
# potassium_isUnacceptable                       0.000000e+00
# sodium                                        -1.121167e-06
# sodium_isUnacceptable                          0.000000e+00
# total_bilirubin                                0.000000e+00
# total_bilirubin_isUnacceptable                 0.000000e+00
# total_bilirubin_isTestnotdone                  0.000000e+00
# serum_protein                                  0.000000e+00
# ...
# SGOT_isTestnotdone                                      0.000000
# BUN                                                     0.000000
# BUN_isUnacceptable                                      0.000000
# BUN_isTestnotdone                                       0.000000
# calcium                                                 0.000000
# calcium_isUnacceptable                                  0.000000
# calcium_isTestnotdone                                   0.000000
# creatinine                                              0.000000
# creatinine_isUnacceptable                               0.000000
# creatinine_isTestnotdone                                0.000000
# potassium                                               0.000000
# potassium_isUnacceptable                                0.000000
# sodium                                                  0.000000
# sodium_isUnacceptable                                   0.000000
# total_bilirubin                                         0.000000
# total_bilirubin_isUnacceptable                          0.000000
# total_bilirubin_isTestnotdone                           0.000000
# serum_protein                                          -0.000021
# red_blood_cells                                         0.000000
# red_blood_cells_isUnacceptable                          0.000000
# red_blood_cells_isBlankbutapplicable                    0.000000
# white_blood_cells                                       0.000000
# white_blood_cells_isUnacceptable                        0.000000
# white_blood_cells_isBlankbutapplicable                  0.000000
# hemoglobin                                              0.000000
# hemoglobin_isMissing                                    0.000000
# hematocrit                                              0.000000
# hematocrit_isUnacceptable                               0.000000
# hematocrit_isMissing                                    0.000000
# platelets_isNormal                                      0.000000
# platelets_isIncreased                                   0.000000
# platelets_isDecreased                                   0.000000
# platelets_isNoestimate                                  0.000000
# segmented_neutrophils                                   0.000030
# lymphocytes                                             0.000000
# monocytes                                               0.000000
# eosinophils                                             0.000000
# basophils                                               0.000000
# band_neutrophils                                        0.000000
# cholesterol                                            -0.000022
# cholesterol_isMissing                                   0.000000
# urine_albumin_isNegative                                0.000000
# urine_albumin_is>=30                                    0.000000
# urine_albumin_is>=100                                   0.000000
# urine_albumin_is>=300                                   0.000000
# urine_albumin_is>=1000                                  0.000000
# urine_albumin_isTrace                                   0.000000
# urine_albumin_isBlankbutapplicable                      0.000000
# urine_glucose_isNegative                                0.000000
# urine_glucose_isLight                                   0.000000
# urine_glucose_isMedium                                  0.000000
# urine_glucose_isDark                                    0.000000
# urine_glucose_isVerydark                                0.000000
# urine_glucose_isTrace                                   0.000000
# urine_glucose_isBlankbutapplicable                      0.000000
# urine_pH                                                0.000088
# urine_pH_isBlankbutapplicable                           0.000000
# urine_hematest_isNegative                               0.000000
# urine_hematest_isSmall                                  0.000000
# urine_hematest_isModerate                               0.000000
# urine_hematest_isLarge                                  0.000000
# urine_hematest_isBlankbutapplicable                     0.000000
# sedimentation_rate                                      0.000000
# sedimentation_rate_isBlankbutapplicable                 0.000000
# uric_acid                                               0.000000
# uric_acid_isUnacceptable                                0.000000
# uric_acid_isTestnotdone                                 0.000000
# systolic_blood_pressure                                -0.000027
# pulse_pressure                                         -0.000008
# bmi                                                     0.000000
#
#                                          systolic_blood_pressure  \
# sex_isFemale                                       -3.355864e-02
# age                                                -7.039897e-01
# physical_activity                                  -5.290380e-03
# serum_albumin                                      -3.402938e-02
# alkaline_phosphatase                                2.868190e-02
# alkaline_phosphatase_isUnacceptable                 3.128900e-04
# alkaline_phosphatase_isTestnotdone                 -2.373968e-04
# SGOT                                               -8.371247e-03
# SGOT_isUnacceptable                                 1.590704e-03
# SGOT_isTestnotdone                                  0.000000e+00
# BUN                                                -5.735706e-04
# BUN_isUnacceptable                                 -2.282662e-06
# BUN_isTestnotdone                                  -6.100932e-05
# calcium                                            -1.086132e-03
# calcium_isUnacceptable                              7.100115e-04
# calcium_isTestnotdone                               0.000000e+00
# creatinine                                         -1.015784e-04
# creatinine_isUnacceptable                           0.000000e+00
# creatinine_isTestnotdone                            0.000000e+00
# potassium                                           5.896685e-03
# potassium_isUnacceptable                            6.889488e-05
# sodium                                             -2.587708e-04
# sodium_isUnacceptable                               0.000000e+00
# total_bilirubin                                     1.295255e-03
# total_bilirubin_isUnacceptable                      3.357588e-04
# total_bilirubin_isTestnotdone                      -1.087377e-04
# serum_protein                                      -1.351367e-02
# red_blood_cells                                    -1.001017e-02
# red_blood_cells_isUnacceptable                     -1.338055e-03
# red_blood_cells_isBlankbutapplicable                1.361296e-04
# white_blood_cells                                  -2.650522e-02
# white_blood_cells_isUnacceptable                    0.000000e+00
# white_blood_cells_isBlankbutapplicable              4.025785e-05
# hemoglobin                                          7.242522e-04
# hemoglobin_isMissing                                0.000000e+00
# hematocrit                                         -2.027584e-02
# hematocrit_isUnacceptable                          -6.556167e-06
# hematocrit_isMissing                                0.000000e+00
# platelets_isNormal                                  7.200760e-05
# platelets_isIncreased                              -1.628990e-05
# platelets_isDecreased                               3.942779e-06
# platelets_isNoestimate                              0.000000e+00
# segmented_neutrophils                               3.911652e-04
# lymphocytes                                        -8.804848e-04
# monocytes                                           1.824054e-03
# eosinophils                                        -8.970082e-04
# basophils                                          -1.768025e-04
# band_neutrophils                                   -3.011038e-04
# cholesterol                                        -2.045693e-02
# cholesterol_isMissing                               0.000000e+00
# urine_albumin_isNegative                            7.779726e-04
# urine_albumin_is>=30                               -1.243013e-04
# urine_albumin_is>=100                              -2.094135e-03
# urine_albumin_is>=300                               1.533534e-04
# urine_albumin_is>=1000                              0.000000e+00
# urine_albumin_isTrace                              -1.046082e-03
# urine_albumin_isBlankbutapplicable                  4.399312e-05
# urine_glucose_isNegative                            1.493556e-02
# urine_glucose_isLight                               0.000000e+00
# urine_glucose_isMedium                              1.272584e-04
# urine_glucose_isDark                                3.721880e-03
# urine_glucose_isVerydark                            4.952027e-03
# urine_glucose_isTrace                              -1.245088e-06
# urine_glucose_isBlankbutapplicable                  0.000000e+00
# urine_pH                                            2.700933e-03
# urine_pH_isBlankbutapplicable                       0.000000e+00
# urine_hematest_isNegative                          -1.556360e-04
# urine_hematest_isSmall                              2.780697e-05
# urine_hematest_isModerate                          -8.300588e-07
# urine_hematest_isLarge                             -3.320235e-06
# urine_hematest_isBlankbutapplicable                 0.000000e+00
# sedimentation_rate                                 -2.782889e-02
# sedimentation_rate_isBlankbutapplicable             1.311493e-04
# uric_acid                                           1.953669e-02
# uric_acid_isUnacceptable                            2.739194e-05
# uric_acid_isTestnotdone                            -2.656188e-05
# systolic_blood_pressure                             0.000000e+00
# pulse_pressure                                     -1.642711e-01
# bmi                                                -1.823997e-02
#
#                                          pulse_pressure           bmi
# sex_isFemale                              -2.769595e-03 -2.625185e-02
# age                                        3.662510e-02 -2.401526e-02
# physical_activity                         -3.928461e-03 -1.159836e-02
# serum_albumin                             -2.837861e-03 -4.234735e-03
# alkaline_phosphatase                       3.935840e-04  5.874119e-03
# alkaline_phosphatase_isUnacceptable        0.000000e+00  0.000000e+00
# alkaline_phosphatase_isTestnotdone        -3.309859e-05  5.416133e-05
# SGOT                                       2.195003e-03  1.815079e-03
# SGOT_isUnacceptable                        5.056355e-04  1.459347e-04
# SGOT_isTestnotdone                        -2.228189e-04 -8.715617e-06
# BUN                                        2.481279e-03  8.416277e-04
# BUN_isUnacceptable                         0.000000e+00  0.000000e+00
# BUN_isTestnotdone                          0.000000e+00 -2.075147e-07
# calcium                                    1.976658e-03 -4.947669e-04
# calcium_isUnacceptable                    -7.444589e-06  5.089428e-04
# calcium_isTestnotdone                      0.000000e+00 -3.112720e-06
# creatinine                                -6.071361e-04  9.045566e-04
# creatinine_isUnacceptable                  0.000000e+00  0.000000e+00
# creatinine_isTestnotdone                   0.000000e+00  0.000000e+00
# potassium                                 -7.104071e-03 -1.358339e-03
# potassium_isUnacceptable                  -7.641728e-05 -1.037573e-05
# sodium                                    -9.890669e-05  9.971599e-04
# sodium_isUnacceptable                      0.000000e+00  0.000000e+00
# total_bilirubin                           -2.397168e-03 -3.374448e-03
# total_bilirubin_isUnacceptable             0.000000e+00  1.031244e-03
# total_bilirubin_isTestnotdone             -8.028224e-06 -9.026889e-06
# serum_protein                              4.734432e-03  3.789737e-05
# red_blood_cells                           -6.361908e-03 -3.376829e-02
# red_blood_cells_isUnacceptable            -4.889721e-03  2.925957e-05
# red_blood_cells_isBlankbutapplicable       0.000000e+00  2.773434e-04
# white_blood_cells                         -2.297146e-03  8.778598e-03
# white_blood_cells_isUnacceptable          -5.628836e-06  0.000000e+00
# white_blood_cells_isBlankbutapplicable     0.000000e+00  3.110645e-04
# hemoglobin                                -3.291825e-03 -7.517375e-03
# hemoglobin_isMissing                       0.000000e+00  0.000000e+00
# hematocrit                                -1.800605e-03 -7.265763e-03
# hematocrit_isUnacceptable                 -4.974841e-04 -3.199877e-04
# hematocrit_isMissing                       0.000000e+00 -2.075147e-05
# platelets_isNormal                         0.000000e+00  1.449490e-04
# platelets_isIncreased                     -7.833680e-06 -4.606826e-05
# platelets_isDecreased                     -1.069998e-05 -1.075445e-04
# platelets_isNoestimate                     0.000000e+00  0.000000e+00
# segmented_neutrophils                     -2.578649e-03  1.275048e-04
# lymphocytes                               -6.759532e-04  2.293582e-03
# monocytes                                 -3.176791e-04 -1.211315e-03
# eosinophils                                6.591891e-04 -3.533310e-03
# basophils                                  6.497804e-05  1.736898e-04
# band_neutrophils                          -1.826932e-04  1.220705e-04
# cholesterol                               -2.366498e-03 -2.890680e-04
# cholesterol_isMissing                      0.000000e+00  0.000000e+00
# urine_albumin_isNegative                  -5.251548e-04 -3.730699e-03
# urine_albumin_is>=30                      -4.060284e-04 -2.075666e-04
# urine_albumin_is>=100                     -3.943817e-04 -3.504508e-03
# urine_albumin_is>=300                     -4.279991e-07 -5.153524e-03
# urine_albumin_is>=1000                    -1.621209e-07  0.000000e+00
# urine_albumin_isTrace                     -7.996254e-04  7.092333e-04
# urine_albumin_isBlankbutapplicable        -1.245737e-04  0.000000e+00
# urine_glucose_isNegative                  -4.768428e-04 -2.580367e-03
# urine_glucose_isLight                      0.000000e+00 -4.420063e-05
# urine_glucose_isMedium                    -3.190538e-06 -9.072543e-04
# urine_glucose_isDark                      -7.775802e-04 -6.691830e-04
# urine_glucose_isVerydark                  -1.497074e-03 -1.073681e-03
# urine_glucose_isTrace                     -2.593934e-07 -3.828646e-05
# urine_glucose_isBlankbutapplicable         0.000000e+00  0.000000e+00
# urine_pH                                   1.891723e-03  6.012323e-03
# urine_pH_isBlankbutapplicable              9.906232e-05  0.000000e+00
# urine_hematest_isNegative                 -1.291455e-05 -5.645437e-04
# urine_hematest_isSmall                     1.920548e-04 -6.619719e-05
# urine_hematest_isModerate                  1.395536e-05  8.902380e-05
# urine_hematest_isLarge                     0.000000e+00 -5.042607e-05
# urine_hematest_isBlankbutapplicable        0.000000e+00  0.000000e+00
# sedimentation_rate                        -9.834653e-03 -2.208475e-04
# sedimentation_rate_isBlankbutapplicable   -2.440814e-03  2.699092e-03
# uric_acid                                 -8.560500e-04 -1.563774e-02
# uric_acid_isUnacceptable                   4.028379e-05  6.650846e-05
# uric_acid_isTestnotdone                   -7.522408e-06  0.000000e+00
# systolic_blood_pressure                   -1.642709e-01 -1.823893e-02
# pulse_pressure                             0.000000e+00 -3.947967e-04
# bmi                                       -3.946629e-04  0.000000e+00

# %% [markdown]
# ## Visualization

# %%
shap_cmap = shap.plots.colors.red_blue
positive_color = shap_cmap(0.0)[:3]
negative_color = shap_cmap(1.0)[:3]

positive_alpha = 0.01
negative_alpha = 0.01
positive_beta = 0
negative_beta = 0

# %%
positive_color
# Out:
# (np.float64(0.0),
#  np.float64(0.5433775692459107),
#  np.float64(0.983379062301401))

# %%
draw(
    psi=psi_2,
    r=r_2,
    psi_q25=psi_1_median,
    psi_q75=psi_1_median,
    r_q25=r_1_q_lower,
    r_q75=r_1_q_upper,
    positive_alpha=positive_alpha,
    negative_alpha=negative_alpha,
    positive_beta=positive_beta,
    negative_beta=negative_beta,
    negative_color=negative_color,
    positive_color=positive_color,
    uncertain_color='grey',
    output_path=os.path.join('..', '..', 'result', 'nhanesi_xgboost_iqr_gamma_25_network.jpg')
)
# Out:
# Saving the graph to ..\..\result\nhanesi_xgboost_iqr_gamma_25_network.jpg

# %%
# Tolerance parameter for percentile-based uncertainty
gamma = 5  # Classical IQR when γ = 25

# Compute percentile bounds
lower_percentile = 50 - gamma  # e.g., 25th percentile when γ = 25
upper_percentile = 50 + gamma  # e.g., 75th percentile when γ = 25

print(f"Using γ = {gamma}")
print(f"Computing {lower_percentile}th and {upper_percentile}th percentiles")
print(f"This means at least {upper_percentile}% of patients must agree on sign for consistent classification")
# Out:
# Using γ = 5
# Computing 45th and 55th percentiles
# This means at least 55% of patients must agree on sign for consistent classification

# %% [markdown]
# ## Build Median-Based SHAP Values (psi_1)

# %%
shap_values_clean = np.nan_to_num(shap_values)
n_features = shap_values_clean.shape[1]

# Calculate median SHAP values across patients
median_shap = np.median(shap_values_clean, axis=0)

# Calculate percentiles using γ parameter
# When γ = 25, this gives classical IQR (25th to 75th percentile)
q_lower_shap = np.percentile(shap_values_clean, lower_percentile, axis=0)
q_upper_shap = np.percentile(shap_values_clean, upper_percentile, axis=0)
iqr_shap = q_upper_shap - q_lower_shap

# Calculate absolute median for normalization
sum_abs_median_shap = np.sum(np.abs(median_shap))

# Build psi matrices
psi_1_median = pd.DataFrame()
psi_1_median['value'] = median_shap / sum_abs_median_shap
psi_1_median['iqr'] = iqr_shap / sum_abs_median_shap
psi_1_median[f'q25'] = q_lower_shap / sum_abs_median_shap
psi_1_median[f'q75'] = q_upper_shap / sum_abs_median_shap
psi_1_median['cv'] = iqr_shap / (np.abs(median_shap) + 1e-10)  # Coefficient of variation
psi_1_median.set_index(X_shapley.columns, inplace=True)

print(f"Median-based node weights (psi) with uncertainty (γ = {gamma}):")
print(psi_1_median.head(10))
# Out:
# Median-based node weights (psi) with uncertainty (γ = 5):
#                                         value       iqr       q25       q75  \
# sex_isFemale                        -0.116573  0.009485 -0.120674 -0.111189
# age                                 -0.569398  0.246471 -0.650465 -0.403994
# physical_activity                   -0.029324  0.002517 -0.030536 -0.028019
# serum_albumin                       -0.032719  0.003621 -0.034240 -0.030619
# alkaline_phosphatase                -0.000573  0.001209 -0.001074  0.000135
# alkaline_phosphatase_isUnacceptable -0.000006  0.000000 -0.000006 -0.000006
# alkaline_phosphatase_isTestnotdone  -0.000050  0.000007 -0.000052 -0.000045
# SGOT                                -0.002691  0.001277 -0.003153 -0.001876
# SGOT_isUnacceptable                 -0.000293  0.000020 -0.000303 -0.000283
# SGOT_isTestnotdone                  -0.000036  0.000002 -0.000038 -0.000036
#
#                                            cv
# sex_isFemale                         0.081364
# age                                  0.432862
# physical_activity                    0.085851
# serum_albumin                        0.110657
# alkaline_phosphatase                 2.108568
# alkaline_phosphatase_isUnacceptable  0.000000
# alkaline_phosphatase_isTestnotdone   0.135857
# SGOT                                 0.474447
# SGOT_isUnacceptable                  0.067157
# SGOT_isTestnotdone                   0.055412

# %% [markdown]
# ## Build Median-Based Interaction Values (r_1)

# %%
# Remove diagonal
n_variables = shap_interaction_values.shape[1]
filtered_shap_interaction_values = np.nan_to_num(shap_interaction_values.copy())
idx_patients = np.repeat(np.arange(num_patients), n_variables)
idx_variables = np.tile(np.arange(n_variables), num_patients)
filtered_shap_interaction_values[idx_patients, idx_variables, idx_variables] = 0

# Calculate median interaction values across patients
median_interaction = np.median(filtered_shap_interaction_values, axis=0)

# Calculate percentiles using γ parameter for interactions
q_lower_interaction = np.percentile(filtered_shap_interaction_values, lower_percentile, axis=0)
q_upper_interaction = np.percentile(filtered_shap_interaction_values, upper_percentile, axis=0)
iqr_interaction = q_upper_interaction - q_lower_interaction

# Normalize
sum_abs_median_interaction = np.sum(np.abs(median_interaction))

# Build r_1 with uncertainty
r_1_median = pd.DataFrame(median_interaction / sum_abs_median_interaction)
r_1_median.rename(columns=dict(list(zip(r_1_median.columns, X_shapley.columns))), inplace=True)
r_1_median.set_index(X_shapley.columns, inplace=True)

# Store IQR separately
r_1_iqr = pd.DataFrame(iqr_interaction / sum_abs_median_interaction)
r_1_iqr.rename(columns=dict(list(zip(r_1_iqr.columns, X_shapley.columns))), inplace=True)
r_1_iqr.set_index(X_shapley.columns, inplace=True)

print(f"\nMedian-based edge weights (r) computed with γ = {gamma}")
print(f"Mean IQR for interactions: {iqr_interaction.mean():.6f}")
# Out:
# Median-based edge weights (r) computed with γ = 5
# Mean IQR for interactions: 0.000028

# %%
# Store lower and upper percentiles for interactions
r_1_q_lower = pd.DataFrame(q_lower_interaction / sum_abs_median_interaction)
r_1_q_lower.rename(columns=dict(list(zip(r_1_q_lower.columns, X_shapley.columns))), inplace=True)
r_1_q_lower.set_index(X_shapley.columns, inplace=True)

r_1_q_upper = pd.DataFrame(q_upper_interaction / sum_abs_median_interaction)
r_1_q_upper.rename(columns=dict(list(zip(r_1_q_upper.columns, X_shapley.columns))), inplace=True)
r_1_q_upper.set_index(X_shapley.columns, inplace=True)

print(f"Lower ({lower_percentile}th) and upper ({upper_percentile}th) percentile dataframes created for interactions")
# Out:
# Lower (45th) and upper (55th) percentile dataframes created for interactions

# %% [markdown]
# ## Normalize Matrices

# %%
from IPython.display import display, Math

# Create psi_1 with just the value column for normalization
psi_1 = psi_1_median[['value']].copy()
psi_2 = normalize_psi(psi_1)
r_2 = normalize_r(r_1_median)

display(Math(r"\mathcal{N}^*_i = \frac{\mathrm{median}_t \left( Sh_{i}(\Delta^{t}) \right)}{\sum_{u=1}^{n} \left| \mathrm{median}_t \left( Sh_{u}(\Delta^{t}) \right) \right|}"))
display(psi_2)
display(Math(r"\mathcal{E}^*_{ij} = \frac{\mathrm{median}_t \left( I_{ij}(\Delta^{t}) \right)}{\sum_{v=1}^{n} \sum_{u > v}^{n} \left| \mathrm{median}_t \left( I_{uv}(\Delta^{t}) \right) \right|}"))
display(r_2)
# Out:
# $\displaystyle \mathcal{N}^*_i = \frac{\mathrm{median}_t \left( Sh_{i}(\Delta^{t}) \right)}{\sum_{u=1}^{n} \left| \mathrm{median}_t \left( Sh_{u}(\Delta^{t}) \right) \right|}$
#                                             value
# sex_isFemale                            -0.204731
# age                                     -1.000000
# physical_activity                       -0.051500
# serum_albumin                           -0.057463
# alkaline_phosphatase                    -0.001007
# alkaline_phosphatase_isUnacceptable     -0.000011
# alkaline_phosphatase_isTestnotdone      -0.000088
# SGOT                                    -0.004726
# SGOT_isUnacceptable                     -0.000515
# SGOT_isTestnotdone                      -0.000064
# BUN                                      0.003906
# BUN_isUnacceptable                      -0.000024
# BUN_isTestnotdone                       -0.000012
# calcium                                  0.001390
# calcium_isUnacceptable                  -0.000716
# calcium_isTestnotdone                   -0.000026
# creatinine                              -0.000099
# creatinine_isUnacceptable                0.000050
# creatinine_isTestnotdone                 0.000000
# potassium                                0.006528
# potassium_isUnacceptable                -0.000030
# sodium                                   0.001450
# sodium_isUnacceptable                   -0.000005
# total_bilirubin                          0.001156
# total_bilirubin_isUnacceptable          -0.000213
# total_bilirubin_isTestnotdone           -0.000015
# serum_protein                           -0.014350
# red_blood_cells                         -0.045425
# red_blood_cells_isUnacceptable          -0.006847
# red_blood_cells_isBlankbutapplicable    -0.000224
# white_blood_cells                       -0.061665
# white_blood_cells_isUnacceptable         0.000003
# white_blood_cells_isBlankbutapplicable  -0.000054
# hemoglobin                              -0.002763
# hemoglobin_isMissing                     0.000000
# hematocrit                              -0.036389
# hematocrit_isUnacceptable               -0.000558
# hematocrit_isMissing                    -0.000009
# platelets_isNormal                       0.000138
# platelets_isIncreased                   -0.000708
# platelets_isDecreased                   -0.000106
# platelets_isNoestimate                   0.000000
# segmented_neutrophils                    0.001099
# lymphocytes                              0.000778
# monocytes                                0.000798
# eosinophils                             -0.000969
# basophils                                0.000142
# band_neutrophils                        -0.000504
# cholesterol                             -0.008756
# cholesterol_isMissing                   -0.000001
# urine_albumin_isNegative                -0.013149
# urine_albumin_is>=30                    -0.000580
# urine_albumin_is>=100                   -0.003566
# urine_albumin_is>=300                   -0.001201
# urine_albumin_is>=1000                  -0.000005
# urine_albumin_isTrace                   -0.001676
# urine_albumin_isBlankbutapplicable      -0.000003
# urine_glucose_isNegative                -0.011278
# urine_glucose_isLight                    0.000014
# urine_glucose_isMedium                  -0.001171
# urine_glucose_isDark                    -0.005337
# urine_glucose_isVerydark                -0.002919
# urine_glucose_isTrace                   -0.000019
# urine_glucose_isBlankbutapplicable       0.000067
# urine_pH                                -0.003704
# urine_pH_isBlankbutapplicable           -0.000029
# urine_hematest_isNegative                0.000811
# urine_hematest_isSmall                   0.000032
# urine_hematest_isModerate               -0.000031
# urine_hematest_isLarge                  -0.000028
# urine_hematest_isBlankbutapplicable      0.000027
# sedimentation_rate                      -0.016083
# sedimentation_rate_isBlankbutapplicable -0.001237
# uric_acid                               -0.022612
# uric_acid_isUnacceptable                 0.000202
# uric_acid_isTestnotdone                  0.000009
# systolic_blood_pressure                 -0.104860
# pulse_pressure                          -0.005231
# bmi                                     -0.042351
# $\displaystyle \mathcal{E}^*_{ij} = \frac{\mathrm{median}_t \left( I_{ij}(\Delta^{t}) \right)}{\sum_{v=1}^{n} \sum_{u > v}^{n} \left| \mathrm{median}_t \left( I_{uv}(\Delta^{t}) \right) \right|}$
#                                          sex_isFemale       age  \
# sex_isFemale                                 0.000000  1.000000
# age                                          0.999979  0.000000
# physical_activity                           -0.101094  0.511696
# serum_albumin                               -0.000867  0.167644
# alkaline_phosphatase                        -0.011105 -0.201740
# alkaline_phosphatase_isUnacceptable          0.000355 -0.000110
# alkaline_phosphatase_isTestnotdone          -0.000364  0.000506
# SGOT                                        -0.001203 -0.093136
# SGOT_isUnacceptable                          0.000000 -0.000693
# SGOT_isTestnotdone                          -0.000185  0.000000
# BUN                                         -0.000810  0.014245
# BUN_isUnacceptable                          -0.000027 -0.000005
# BUN_isTestnotdone                            0.000000  0.000000
# calcium                                     -0.004286  0.000852
# calcium_isUnacceptable                       0.000050  0.000346
# calcium_isTestnotdone                        0.000000  0.000113
# creatinine                                  -0.000082  0.000230
# creatinine_isUnacceptable                    0.000045  0.000000
# creatinine_isTestnotdone                     0.000000  0.000000
# potassium                                   -0.001071  0.025624
# potassium_isUnacceptable                     0.000000  0.000000
# sodium                                      -0.000980  0.010102
# sodium_isUnacceptable                       -0.000003  0.000000
# total_bilirubin                              0.006497  0.008442
# total_bilirubin_isUnacceptable              -0.000406  0.000046
# total_bilirubin_isTestnotdone               -0.000656 -0.000007
# serum_protein                               -0.001278 -0.237867
# red_blood_cells                              0.014365  0.033322
# red_blood_cells_isUnacceptable               0.000000  0.008233
# red_blood_cells_isBlankbutapplicable        -0.001398 -0.000075
# white_blood_cells                            0.047869 -0.026930
# white_blood_cells_isUnacceptable             0.000000  0.000470
# white_blood_cells_isBlankbutapplicable       0.000000  0.000000
# hemoglobin                                  -0.026634 -0.026667
# hemoglobin_isMissing                         0.000000  0.000000
# hematocrit                                  -0.056395  0.065696
# hematocrit_isUnacceptable                    0.000447  0.001243
# hematocrit_isMissing                         0.000000 -0.000001
# platelets_isNormal                           0.000000  0.000158
# platelets_isIncreased                        0.000195 -0.000222
# platelets_isDecreased                        0.000000  0.000003
# platelets_isNoestimate                       0.000000  0.000000
# segmented_neutrophils                        0.001201 -0.001329
# lymphocytes                                 -0.003123 -0.000825
# monocytes                                   -0.000483 -0.001492
# eosinophils                                 -0.000123  0.001025
# basophils                                    0.000000 -0.001144
# band_neutrophils                             0.000691 -0.000208
# cholesterol                                  0.000194 -0.088048
# cholesterol_isMissing                        0.000047  0.000000
# urine_albumin_isNegative                     0.000566  0.001781
# urine_albumin_is>=30                         0.000000 -0.000085
# urine_albumin_is>=100                       -0.000781 -0.004615
# urine_albumin_is>=300                        0.000853 -0.000759
# urine_albumin_is>=1000                       0.000000  0.000000
# urine_albumin_isTrace                       -0.000203 -0.001671
# urine_albumin_isBlankbutapplicable           0.000000  0.000199
# urine_glucose_isNegative                    -0.017602  0.075199
# urine_glucose_isLight                       -0.000115  0.000000
# urine_glucose_isMedium                      -0.001127  0.000033
# urine_glucose_isDark                        -0.010958 -0.002906
# urine_glucose_isVerydark                    -0.001371  0.007246
# urine_glucose_isTrace                        0.000000  0.000000
# urine_glucose_isBlankbutapplicable           0.000000 -0.000920
# urine_pH                                     0.000085 -0.001100
# urine_pH_isBlankbutapplicable                0.000000  0.000000
# urine_hematest_isNegative                    0.002247  0.000757
# urine_hematest_isSmall                       0.000000 -0.000425
# urine_hematest_isModerate                    0.000000 -0.000052
# urine_hematest_isLarge                       0.000000  0.000173
# urine_hematest_isBlankbutapplicable          0.000000  0.000000
# sedimentation_rate                          -0.270468  0.044321
# sedimentation_rate_isBlankbutapplicable      0.000000  0.001233
# uric_acid                                   -0.014899  0.008241
# uric_acid_isUnacceptable                    -0.000097 -0.000236
# uric_acid_isTestnotdone                      0.000000  0.000014
# systolic_blood_pressure                     -0.033557 -0.704008
# pulse_pressure                              -0.002769  0.036611
# bmi                                         -0.026253 -0.024007
#
#                                          physical_activity  serum_albumin  \
# sex_isFemale                                 -1.010934e-01  -8.675152e-04
# age                                           5.116979e-01   1.676468e-01
# physical_activity                             0.000000e+00   5.926008e-02
# serum_albumin                                 5.926028e-02   0.000000e+00
# alkaline_phosphatase                         -4.952509e-02  -1.481110e-03
# alkaline_phosphatase_isUnacceptable           0.000000e+00   0.000000e+00
# alkaline_phosphatase_isTestnotdone            0.000000e+00  -2.510928e-05
# SGOT                                         -1.824832e-03   2.248110e-03
# SGOT_isUnacceptable                           1.827167e-04  -1.267915e-04
# SGOT_isTestnotdone                            0.000000e+00  -5.768908e-05
# BUN                                          -6.417392e-04   9.452294e-04
# BUN_isUnacceptable                            0.000000e+00   0.000000e+00
# BUN_isTestnotdone                             0.000000e+00   0.000000e+00
# calcium                                      -1.585412e-04  -3.118946e-04
# calcium_isUnacceptable                        0.000000e+00  -9.950329e-05
# calcium_isTestnotdone                         0.000000e+00   6.422579e-05
# creatinine                                   -1.178165e-03   6.308446e-05
# creatinine_isUnacceptable                     0.000000e+00   0.000000e+00
# creatinine_isTestnotdone                      0.000000e+00   0.000000e+00
# potassium                                    -1.672776e-03   3.223896e-03
# potassium_isUnacceptable                     -5.187867e-07   0.000000e+00
# sodium                                       -1.700583e-04   7.714359e-04
# sodium_isUnacceptable                         0.000000e+00  -1.037573e-07
# total_bilirubin                              -7.255232e-04  -1.015006e-03
# total_bilirubin_isUnacceptable               -1.750386e-04   0.000000e+00
# total_bilirubin_isTestnotdone                -2.199656e-05   0.000000e+00
# serum_protein                                -7.549384e-04  -2.179738e-01
# red_blood_cells                              -1.863446e-02  -1.174844e-02
# red_blood_cells_isUnacceptable                2.776547e-03  -3.222496e-03
# red_blood_cells_isBlankbutapplicable          0.000000e+00   3.652259e-05
# white_blood_cells                            -2.250263e-02  -1.765003e-02
# white_blood_cells_isUnacceptable              0.000000e+00  -8.881629e-05
# white_blood_cells_isBlankbutapplicable        5.999250e-04   0.000000e+00
# hemoglobin                                   -4.359624e-04  -1.643273e-02
# hemoglobin_isMissing                          0.000000e+00   0.000000e+00
# hematocrit                                   -1.388937e-02   1.293813e-02
# hematocrit_isUnacceptable                     4.310080e-04  -3.318160e-04
# hematocrit_isMissing                          0.000000e+00   0.000000e+00
# platelets_isNormal                            0.000000e+00  -4.461566e-05
# platelets_isIncreased                        -1.552210e-04  -9.338161e-07
# platelets_isDecreased                         0.000000e+00  -5.447261e-05
# platelets_isNoestimate                        0.000000e+00   0.000000e+00
# segmented_neutrophils                        -7.162473e-03  -6.629576e-04
# lymphocytes                                  -6.212938e-03  -7.953357e-04
# monocytes                                    -3.966124e-04  -9.394709e-04
# eosinophils                                  -5.727302e-03  -6.183322e-04
# basophils                                     0.000000e+00   2.118466e-04
# band_neutrophils                              5.084110e-05   6.178750e-05
# cholesterol                                   4.365232e-02   1.672179e-02
# cholesterol_isMissing                         0.000000e+00   0.000000e+00
# urine_albumin_isNegative                      1.650831e-03   6.728353e-03
# urine_albumin_is>=30                         -9.119752e-04   1.958939e-04
# urine_albumin_is>=100                        -2.115612e-04  -1.200888e-03
# urine_albumin_is>=300                        -1.576074e-04   2.537386e-04
# urine_albumin_is>=1000                        0.000000e+00   0.000000e+00
# urine_albumin_isTrace                         1.354422e-03   2.579615e-03
# urine_albumin_isBlankbutapplicable            0.000000e+00  -3.579628e-04
# urine_glucose_isNegative                     -3.500047e-03  -6.714138e-03
# urine_glucose_isLight                         0.000000e+00   0.000000e+00
# urine_glucose_isMedium                       -6.671597e-04  -2.798699e-03
# urine_glucose_isDark                         -6.031414e-04  -8.744928e-04
# urine_glucose_isVerydark                     -1.917436e-04  -2.015071e-03
# urine_glucose_isTrace                        -1.218111e-04   0.000000e+00
# urine_glucose_isBlankbutapplicable            0.000000e+00   0.000000e+00
# urine_pH                                      1.866283e-03   6.244208e-03
# urine_pH_isBlankbutapplicable                 4.326681e-05   0.000000e+00
# urine_hematest_isNegative                    -1.034461e-04   2.661376e-04
# urine_hematest_isSmall                        0.000000e+00   0.000000e+00
# urine_hematest_isModerate                    -2.386419e-05   7.864807e-05
# urine_hematest_isLarge                        0.000000e+00   0.000000e+00
# urine_hematest_isBlankbutapplicable           0.000000e+00   0.000000e+00
# sedimentation_rate                            3.237707e-02  -2.201176e-02
# sedimentation_rate_isBlankbutapplicable      -3.216478e-05   1.254426e-04
# uric_acid                                     4.456586e-03   2.439081e-02
# uric_acid_isUnacceptable                     -1.028235e-04  -1.411100e-05
# uric_acid_isTestnotdone                       0.000000e+00   5.789660e-05
# systolic_blood_pressure                      -5.289031e-03  -3.402888e-02
# pulse_pressure                               -3.928461e-03  -2.837737e-03
# bmi                                          -1.159784e-02  -4.234597e-03
#
#                                          alkaline_phosphatase  \
# sex_isFemale                                    -1.110488e-02
# age                                             -2.017405e-01
# physical_activity                               -4.952560e-02
# serum_albumin                                   -1.480964e-03
# alkaline_phosphatase                             0.000000e+00
# alkaline_phosphatase_isUnacceptable              0.000000e+00
# alkaline_phosphatase_isTestnotdone               0.000000e+00
# SGOT                                            -1.477756e-01
# SGOT_isUnacceptable                              8.300588e-07
# SGOT_isTestnotdone                               0.000000e+00
# BUN                                             -4.218851e-02
# BUN_isUnacceptable                               1.933778e-04
# BUN_isTestnotdone                                0.000000e+00
# calcium                                         -2.450578e-02
# calcium_isUnacceptable                           3.134743e-03
# calcium_isTestnotdone                            0.000000e+00
# creatinine                                       8.561926e-04
# creatinine_isUnacceptable                        0.000000e+00
# creatinine_isTestnotdone                         0.000000e+00
# potassium                                       -2.505716e-02
# potassium_isUnacceptable                         0.000000e+00
# sodium                                          -7.220558e-03
# sodium_isUnacceptable                            0.000000e+00
# total_bilirubin                                 -5.000849e-02
# total_bilirubin_isUnacceptable                  -4.937715e-04
# total_bilirubin_isTestnotdone                    0.000000e+00
# serum_protein                                    2.863826e-03
# red_blood_cells                                 -3.449937e-03
# red_blood_cells_isUnacceptable                  -1.298834e-03
# red_blood_cells_isBlankbutapplicable             4.515649e-04
# white_blood_cells                               -1.075163e-03
# white_blood_cells_isUnacceptable                 4.035253e-04
# white_blood_cells_isBlankbutapplicable          -5.333776e-06
# hemoglobin                                       2.414317e-03
# hemoglobin_isMissing                             0.000000e+00
# hematocrit                                      -4.840571e-03
# hematocrit_isUnacceptable                       -1.331207e-04
# hematocrit_isMissing                            -3.112720e-07
# platelets_isNormal                              -1.256670e-03
# platelets_isIncreased                           -2.022101e-03
# platelets_isDecreased                            5.628836e-06
# platelets_isNoestimate                           0.000000e+00
# segmented_neutrophils                            4.017707e-03
# lymphocytes                                     -5.443564e-03
# monocytes                                        4.262806e-03
# eosinophils                                     -3.542159e-03
# basophils                                       -4.580887e-05
# band_neutrophils                                -2.452203e-03
# cholesterol                                      2.097463e-02
# cholesterol_isMissing                            0.000000e+00
# urine_albumin_isNegative                         9.063723e-04
# urine_albumin_is>=30                             9.587179e-05
# urine_albumin_is>=100                           -5.447266e-03
# urine_albumin_is>=300                           -1.466869e-04
# urine_albumin_is>=1000                           0.000000e+00
# urine_albumin_isTrace                           -9.673103e-05
# urine_albumin_isBlankbutapplicable               4.388936e-05
# urine_glucose_isNegative                        -3.798025e-03
# urine_glucose_isLight                            0.000000e+00
# urine_glucose_isMedium                          -8.425680e-04
# urine_glucose_isDark                            -3.693891e-04
# urine_glucose_isVerydark                        -1.607461e-04
# urine_glucose_isTrace                            0.000000e+00
# urine_glucose_isBlankbutapplicable               0.000000e+00
# urine_pH                                         2.857763e-03
# urine_pH_isBlankbutapplicable                    4.329275e-05
# urine_hematest_isNegative                        1.215777e-04
# urine_hematest_isSmall                           0.000000e+00
# urine_hematest_isModerate                        0.000000e+00
# urine_hematest_isLarge                           1.543391e-06
# urine_hematest_isBlankbutapplicable              0.000000e+00
# sedimentation_rate                              -1.258929e-02
# sedimentation_rate_isBlankbutapplicable          2.659560e-04
# uric_acid                                       -8.884527e-02
# uric_acid_isUnacceptable                        -6.699644e-07
# uric_acid_isTestnotdone                          0.000000e+00
# systolic_blood_pressure                          2.868154e-02
# pulse_pressure                                   3.935905e-04
# bmi                                              5.874686e-03
#
#                                          alkaline_phosphatase_isUnacceptable  \
# sex_isFemale                                                        0.000355
# age                                                                -0.000110
# physical_activity                                                   0.000000
# serum_albumin                                                       0.000000
# alkaline_phosphatase                                                0.000000
# alkaline_phosphatase_isUnacceptable                                 0.000000
# alkaline_phosphatase_isTestnotdone                                  0.000000
# SGOT                                                                0.000000
# SGOT_isUnacceptable                                                 0.000000
# SGOT_isTestnotdone                                                  0.000000
# BUN                                                                 0.000000
# BUN_isUnacceptable                                                  0.000000
# BUN_isTestnotdone                                                   0.000000
# calcium                                                             0.000000
# calcium_isUnacceptable                                              0.000000
# calcium_isTestnotdone                                               0.000000
# creatinine                                                          0.000000
# creatinine_isUnacceptable                                           0.000000
# creatinine_isTestnotdone                                            0.000000
# potassium                                                           0.000000
# potassium_isUnacceptable                                            0.000000
# sodium                                                              0.000000
# sodium_isUnacceptable                                               0.000000
# total_bilirubin                                                     0.000000
# total_bilirubin_isUnacceptable                                      0.000000
# total_bilirubin_isTestnotdone                                       0.000000
# serum_protein                                                       0.000000
# red_blood_cells                                                    -0.000005
# red_blood_cells_isUnacceptable                                      0.000000
# red_blood_cells_isBlankbutapplicable                                0.000000
# white_blood_cells                                                   0.000000
# white_blood_cells_isUnacceptable                                    0.000000
# white_blood_cells_isBlankbutapplicable                              0.000000
# hemoglobin                                                          0.000000
# hemoglobin_isMissing                                                0.000000
# hematocrit                                                          0.000000
# hematocrit_isUnacceptable                                           0.000000
# hematocrit_isMissing                                                0.000000
# platelets_isNormal                                                  0.000000
# platelets_isIncreased                                               0.000000
# platelets_isDecreased                                               0.000000
# platelets_isNoestimate                                              0.000000
# segmented_neutrophils                                               0.000000
# lymphocytes                                                         0.000000
# monocytes                                                           0.000000
# eosinophils                                                         0.000000
# basophils                                                           0.000000
# band_neutrophils                                                    0.000000
# cholesterol                                                         0.000000
# cholesterol_isMissing                                               0.000000
# urine_albumin_isNegative                                            0.000000
# urine_albumin_is>=30                                                0.000000
# urine_albumin_is>=100                                               0.000000
# urine_albumin_is>=300                                               0.000000
# urine_albumin_is>=1000                                              0.000000
# urine_albumin_isTrace                                               0.000000
# urine_albumin_isBlankbutapplicable                                  0.000000
# urine_glucose_isNegative                                            0.000000
# urine_glucose_isLight                                               0.000000
# urine_glucose_isMedium                                              0.000000
# urine_glucose_isDark                                               -0.000187
# urine_glucose_isVerydark                                            0.000000
# urine_glucose_isTrace                                               0.000000
# urine_glucose_isBlankbutapplicable                                  0.000000
# urine_pH                                                            0.000000
# urine_pH_isBlankbutapplicable                                       0.000000
# urine_hematest_isNegative                                           0.000000
# urine_hematest_isSmall                                              0.000000
# urine_hematest_isModerate                                           0.000000
# urine_hematest_isLarge                                              0.000000
# urine_hematest_isBlankbutapplicable                                 0.000000
# sedimentation_rate                                                  0.000034
# sedimentation_rate_isBlankbutapplicable                             0.000000
# uric_acid                                                           0.000000
# uric_acid_isUnacceptable                                            0.000000
# uric_acid_isTestnotdone                                             0.000000
# systolic_blood_pressure                                             0.000313
# pulse_pressure                                                      0.000000
# bmi                                                                 0.000000
#
#                                          alkaline_phosphatase_isTestnotdone  \
# sex_isFemale                                                  -3.645123e-04
# age                                                            5.118968e-04
# physical_activity                                              0.000000e+00
# serum_albumin                                                 -2.510730e-05
# alkaline_phosphatase                                           0.000000e+00
# alkaline_phosphatase_isUnacceptable                            0.000000e+00
# alkaline_phosphatase_isTestnotdone                             0.000000e+00
# SGOT                                                          -4.677187e-07
# SGOT_isUnacceptable                                            0.000000e+00
# SGOT_isTestnotdone                                             0.000000e+00
# BUN                                                            0.000000e+00
# BUN_isUnacceptable                                             0.000000e+00
# BUN_isTestnotdone                                              0.000000e+00
# calcium                                                        0.000000e+00
# calcium_isUnacceptable                                         0.000000e+00
# calcium_isTestnotdone                                          0.000000e+00
# creatinine                                                     0.000000e+00
# creatinine_isUnacceptable                                      0.000000e+00
# creatinine_isTestnotdone                                       0.000000e+00
# potassium                                                      0.000000e+00
# potassium_isUnacceptable                                       0.000000e+00
# sodium                                                         0.000000e+00
# sodium_isUnacceptable                                          0.000000e+00
# total_bilirubin                                                0.000000e+00
# total_bilirubin_isUnacceptable                                 0.000000e+00
# total_bilirubin_isTestnotdone                                  0.000000e+00
# serum_protein                                                 -2.220752e-06
# red_blood_cells                                                8.796292e-05
# red_blood_cells_isUnacceptable                                 3.044534e-04
# red_blood_cells_isBlankbutapplicable                           0.000000e+00
# white_blood_cells                                              7.418448e-06
# white_blood_cells_isUnacceptable                               0.000000e+00
# white_blood_cells_isBlankbutapplicable                         0.000000e+00
# hemoglobin                                                     8.604200e-05
# hemoglobin_isMissing                                           0.000000e+00
# hematocrit                                                     1.667687e-05
# hematocrit_isUnacceptable                                      0.000000e+00
# hematocrit_isMissing                                           0.000000e+00
# platelets_isNormal                                             0.000000e+00
# platelets_isIncreased                                          0.000000e+00
# platelets_isDecreased                                          0.000000e+00
# platelets_isNoestimate                                         0.000000e+00
# segmented_neutrophils                                          0.000000e+00
# lymphocytes                                                    0.000000e+00
# monocytes                                                      0.000000e+00
# eosinophils                                                    0.000000e+00
# basophils                                                      0.000000e+00
# band_neutrophils                                               0.000000e+00
# cholesterol                                                   -5.906539e-04
# cholesterol_isMissing                                          0.000000e+00
# urine_albumin_isNegative                                       0.000000e+00
# urine_albumin_is>=30                                           0.000000e+00
# urine_albumin_is>=100                                          0.000000e+00
# urine_albumin_is>=300                                          0.000000e+00
# urine_albumin_is>=1000                                         0.000000e+00
# urine_albumin_isTrace                                         -2.221056e-07
# urine_albumin_isBlankbutapplicable                             0.000000e+00
# urine_glucose_isNegative                                       0.000000e+00
# urine_glucose_isLight                                          0.000000e+00
# urine_glucose_isMedium                                         0.000000e+00
# urine_glucose_isDark                                           0.000000e+00
# urine_glucose_isVerydark                                       0.000000e+00
# urine_glucose_isTrace                                          0.000000e+00
# urine_glucose_isBlankbutapplicable                             0.000000e+00
# urine_pH                                                       0.000000e+00
# urine_pH_isBlankbutapplicable                                  0.000000e+00
# urine_hematest_isNegative                                      0.000000e+00
# urine_hematest_isSmall                                         0.000000e+00
# urine_hematest_isModerate                                      0.000000e+00
# urine_hematest_isLarge                                         0.000000e+00
# urine_hematest_isBlankbutapplicable                            0.000000e+00
# sedimentation_rate                                             7.531649e-05
# sedimentation_rate_isBlankbutapplicable                        0.000000e+00
# uric_acid                                                      0.000000e+00
# uric_acid_isUnacceptable                                       0.000000e+00
# uric_acid_isTestnotdone                                        0.000000e+00
# systolic_blood_pressure                                       -2.373776e-04
# pulse_pressure                                                -3.308177e-05
# bmi                                                            5.417258e-05
#
#                                                  SGOT  SGOT_isUnacceptable  \
# sex_isFemale                            -1.202165e-03         0.000000e+00
# age                                     -9.312669e-02        -6.928234e-04
# physical_activity                       -1.825000e-03         1.828002e-04
# serum_albumin                            2.247896e-03        -1.268190e-04
# alkaline_phosphatase                    -1.477755e-01         8.487027e-07
# alkaline_phosphatase_isUnacceptable      0.000000e+00         0.000000e+00
# alkaline_phosphatase_isTestnotdone      -4.669080e-07         0.000000e+00
# SGOT                                     0.000000e+00         2.721199e-05
# SGOT_isUnacceptable                      2.721036e-05         0.000000e+00
# SGOT_isTestnotdone                       0.000000e+00         0.000000e+00
# BUN                                     -7.410447e-03        -1.166460e-06
# BUN_isUnacceptable                       0.000000e+00         0.000000e+00
# BUN_isTestnotdone                       -4.669080e-07         0.000000e+00
# calcium                                 -2.152096e-03        -3.572479e-04
# calcium_isUnacceptable                  -4.244453e-04         0.000000e+00
# calcium_isTestnotdone                    0.000000e+00         0.000000e+00
# creatinine                              -1.207073e-03         0.000000e+00
# creatinine_isUnacceptable                0.000000e+00         0.000000e+00
# creatinine_isTestnotdone                 0.000000e+00         0.000000e+00
# potassium                               -1.588367e-02         0.000000e+00
# potassium_isUnacceptable                 0.000000e+00         0.000000e+00
# sodium                                  -8.415016e-03         0.000000e+00
# sodium_isUnacceptable                    0.000000e+00         0.000000e+00
# total_bilirubin                         -1.280979e-02        -8.166765e-04
# total_bilirubin_isUnacceptable           0.000000e+00         0.000000e+00
# total_bilirubin_isTestnotdone            0.000000e+00         0.000000e+00
# serum_protein                            1.710905e-03         3.072758e-05
# red_blood_cells                         -7.657039e-03        -5.111670e-04
# red_blood_cells_isUnacceptable          -2.116390e-04         0.000000e+00
# red_blood_cells_isBlankbutapplicable     0.000000e+00         0.000000e+00
# white_blood_cells                        9.248970e-04         3.505450e-04
# white_blood_cells_isUnacceptable         1.021102e-04         0.000000e+00
# white_blood_cells_isBlankbutapplicable   0.000000e+00         0.000000e+00
# hemoglobin                              -6.247197e-04         8.872712e-05
# hemoglobin_isMissing                     0.000000e+00         0.000000e+00
# hematocrit                               6.456787e-04        -6.600998e-04
# hematocrit_isUnacceptable               -3.864961e-06         0.000000e+00
# hematocrit_isMissing                     0.000000e+00         0.000000e+00
# platelets_isNormal                       0.000000e+00         7.207731e-05
# platelets_isIncreased                   -9.335567e-05         0.000000e+00
# platelets_isDecreased                    6.754603e-05        -3.455606e-06
# platelets_isNoestimate                   0.000000e+00         0.000000e+00
# segmented_neutrophils                   -5.922045e-02         1.226217e-04
# lymphocytes                             -8.633804e-03         5.437858e-05
# monocytes                                1.198979e-03         0.000000e+00
# eosinophils                             -5.510776e-03         1.270468e-04
# basophils                                4.951819e-05         0.000000e+00
# band_neutrophils                        -2.647109e-05         9.138104e-04
# cholesterol                              1.508677e-03         1.040046e-04
# cholesterol_isMissing                    0.000000e+00         0.000000e+00
# urine_albumin_isNegative                 3.206556e-03         2.563062e-04
# urine_albumin_is>=30                    -1.609795e-04         0.000000e+00
# urine_albumin_is>=100                   -1.669974e-03        -3.749045e-06
# urine_albumin_is>=300                   -5.844132e-05         0.000000e+00
# urine_albumin_is>=1000                   0.000000e+00         0.000000e+00
# urine_albumin_isTrace                   -1.182313e-03         1.595942e-04
# urine_albumin_isBlankbutapplicable       0.000000e+00         0.000000e+00
# urine_glucose_isNegative                 1.659599e-04         0.000000e+00
# urine_glucose_isLight                    0.000000e+00         0.000000e+00
# urine_glucose_isMedium                  -9.317410e-05         0.000000e+00
# urine_glucose_isDark                    -1.177646e-03        -1.104124e-05
# urine_glucose_isVerydark                 4.758377e-04        -5.504003e-07
# urine_glucose_isTrace                    0.000000e+00         0.000000e+00
# urine_glucose_isBlankbutapplicable       0.000000e+00         0.000000e+00
# urine_pH                                -1.695071e-04         0.000000e+00
# urine_pH_isBlankbutapplicable           -1.110204e-05         0.000000e+00
# urine_hematest_isNegative               -3.968718e-06         0.000000e+00
# urine_hematest_isSmall                   0.000000e+00         0.000000e+00
# urine_hematest_isModerate                0.000000e+00         0.000000e+00
# urine_hematest_isLarge                   0.000000e+00         0.000000e+00
# urine_hematest_isBlankbutapplicable      0.000000e+00         0.000000e+00
# sedimentation_rate                      -1.179220e-02        -4.671512e-05
# sedimentation_rate_isBlankbutapplicable  8.692271e-05         0.000000e+00
# uric_acid                               -8.081956e-03         0.000000e+00
# uric_acid_isUnacceptable                 0.000000e+00         0.000000e+00
# uric_acid_isTestnotdone                  0.000000e+00         0.000000e+00
# systolic_blood_pressure                 -8.371217e-03         1.590914e-03
# pulse_pressure                           2.195101e-03         5.056256e-04
# bmi                                      1.814577e-03         1.458950e-04
#
#                                          SGOT_isTestnotdone           BUN  \
# sex_isFemale                                      -0.000185 -8.097774e-04
# age                                                0.000000  1.423905e-02
# physical_activity                                  0.000000 -6.417943e-04
# serum_albumin                                     -0.000058  9.452684e-04
# alkaline_phosphatase                               0.000000 -4.218853e-02
# alkaline_phosphatase_isUnacceptable                0.000000  0.000000e+00
# alkaline_phosphatase_isTestnotdone                 0.000000  0.000000e+00
# SGOT                                               0.000000 -7.410476e-03
# SGOT_isUnacceptable                                0.000000 -1.167270e-06
# SGOT_isTestnotdone                                 0.000000  0.000000e+00
# BUN                                                0.000000  0.000000e+00
# BUN_isUnacceptable                                 0.000000  0.000000e+00
# BUN_isTestnotdone                                  0.000000  0.000000e+00
# calcium                                            0.000000 -1.222373e-02
# calcium_isUnacceptable                             0.000000  0.000000e+00
# calcium_isTestnotdone                              0.000000  0.000000e+00
# creatinine                                         0.000000  1.774173e-03
# creatinine_isUnacceptable                          0.000000  0.000000e+00
# creatinine_isTestnotdone                           0.000000  0.000000e+00
# potassium                                         -0.000007 -5.784410e-03
# potassium_isUnacceptable                           0.000000  0.000000e+00
# sodium                                             0.000000 -6.083890e-03
# sodium_isUnacceptable                              0.000000  0.000000e+00
# total_bilirubin                                    0.000014 -4.111346e-03
# total_bilirubin_isUnacceptable                     0.000000  0.000000e+00
# total_bilirubin_isTestnotdone                      0.000000  0.000000e+00
# serum_protein                                      0.000000  1.223105e-04
# red_blood_cells                                    0.000156 -1.899162e-03
# red_blood_cells_isUnacceptable                     0.000000 -2.308770e-03
# red_blood_cells_isBlankbutapplicable               0.000000 -2.120541e-06
# white_blood_cells                                 -0.000024 -1.476856e-04
# white_blood_cells_isUnacceptable                   0.000000  0.000000e+00
# white_blood_cells_isBlankbutapplicable             0.000000 -9.727251e-08
# hemoglobin                                        -0.000501  1.105061e-03
# hemoglobin_isMissing                               0.000000  0.000000e+00
# hematocrit                                         0.000000 -4.139147e-03
# hematocrit_isUnacceptable                          0.000000 -2.717145e-06
# hematocrit_isMissing                               0.000000  0.000000e+00
# platelets_isNormal                                 0.000000  0.000000e+00
# platelets_isIncreased                              0.000000  2.088117e-06
# platelets_isDecreased                              0.000000 -1.426664e-07
# platelets_isNoestimate                             0.000000  0.000000e+00
# segmented_neutrophils                              0.000000  4.653517e-05
# lymphocytes                                        0.000096  1.187535e-04
# monocytes                                          0.000000 -2.672621e-03
# eosinophils                                        0.000000  2.576814e-04
# basophils                                          0.000000  0.000000e+00
# band_neutrophils                                   0.000000  3.170435e-05
# cholesterol                                        0.000000  1.860820e-03
# cholesterol_isMissing                              0.000000  0.000000e+00
# urine_albumin_isNegative                           0.000000 -1.968030e-03
# urine_albumin_is>=30                               0.000000 -1.416936e-05
# urine_albumin_is>=100                              0.000000 -7.377439e-04
# urine_albumin_is>=300                              0.000000 -1.623802e-05
# urine_albumin_is>=1000                             0.000000  0.000000e+00
# urine_albumin_isTrace                              0.000000 -4.287124e-04
# urine_albumin_isBlankbutapplicable                 0.000000  0.000000e+00
# urine_glucose_isNegative                           0.000000  9.435433e-06
# urine_glucose_isLight                              0.000000  0.000000e+00
# urine_glucose_isMedium                             0.000000 -1.482433e-05
# urine_glucose_isDark                               0.000000  3.005072e-05
# urine_glucose_isVerydark                           0.000000 -3.487414e-04
# urine_glucose_isTrace                              0.000000  0.000000e+00
# urine_glucose_isBlankbutapplicable                 0.000000  0.000000e+00
# urine_pH                                           0.000000  1.086048e-04
# urine_pH_isBlankbutapplicable                      0.000000  0.000000e+00
# urine_hematest_isNegative                          0.000000  3.455119e-05
# urine_hematest_isSmall                             0.000000  0.000000e+00
# urine_hematest_isModerate                          0.000000  1.945450e-06
# urine_hematest_isLarge                             0.000000  0.000000e+00
# urine_hematest_isBlankbutapplicable                0.000000  0.000000e+00
# sedimentation_rate                                 0.000000  3.690227e-04
# sedimentation_rate_isBlankbutapplicable            0.000000 -1.234712e-05
# uric_acid                                          0.000000  1.358025e-02
# uric_acid_isUnacceptable                           0.000000 -3.047872e-07
# uric_acid_isTestnotdone                            0.000000  0.000000e+00
# systolic_blood_pressure                            0.000000 -5.732950e-04
# pulse_pressure                                    -0.000223  2.481201e-03
# bmi                                               -0.000009  8.416666e-04
#
#                                          BUN_isUnacceptable  \
# sex_isFemale                                  -2.723635e-05
# age                                           -4.879863e-06
# physical_activity                              0.000000e+00
# serum_albumin                                  0.000000e+00
# alkaline_phosphatase                           1.933804e-04
# alkaline_phosphatase_isUnacceptable            0.000000e+00
# alkaline_phosphatase_isTestnotdone             0.000000e+00
# SGOT                                           0.000000e+00
# SGOT_isUnacceptable                            0.000000e+00
# SGOT_isTestnotdone                             0.000000e+00
# BUN                                            0.000000e+00
# BUN_isUnacceptable                             0.000000e+00
# BUN_isTestnotdone                              0.000000e+00
# calcium                                        0.000000e+00
# calcium_isUnacceptable                         0.000000e+00
# calcium_isTestnotdone                          0.000000e+00
# creatinine                                     0.000000e+00
# creatinine_isUnacceptable                      0.000000e+00
# creatinine_isTestnotdone                       0.000000e+00
# potassium                                      0.000000e+00
# potassium_isUnacceptable                       0.000000e+00
# sodium                                        -1.121167e-06
# sodium_isUnacceptable                          0.000000e+00
# total_bilirubin                                0.000000e+00
# total_bilirubin_isUnacceptable                 0.000000e+00
# total_bilirubin_isTestnotdone                  0.000000e+00
# serum_protein                                  0.000000e+00
# ...
# SGOT_isTestnotdone                                      0.000000
# BUN                                                     0.000000
# BUN_isUnacceptable                                      0.000000
# BUN_isTestnotdone                                       0.000000
# calcium                                                 0.000000
# calcium_isUnacceptable                                  0.000000
# calcium_isTestnotdone                                   0.000000
# creatinine                                              0.000000
# creatinine_isUnacceptable                               0.000000
# creatinine_isTestnotdone                                0.000000
# potassium                                               0.000000
# potassium_isUnacceptable                                0.000000
# sodium                                                  0.000000
# sodium_isUnacceptable                                   0.000000
# total_bilirubin                                         0.000000
# total_bilirubin_isUnacceptable                          0.000000
# total_bilirubin_isTestnotdone                           0.000000
# serum_protein                                          -0.000021
# red_blood_cells                                         0.000000
# red_blood_cells_isUnacceptable                          0.000000
# red_blood_cells_isBlankbutapplicable                    0.000000
# white_blood_cells                                       0.000000
# white_blood_cells_isUnacceptable                        0.000000
# white_blood_cells_isBlankbutapplicable                  0.000000
# hemoglobin                                              0.000000
# hemoglobin_isMissing                                    0.000000
# hematocrit                                              0.000000
# hematocrit_isUnacceptable                               0.000000
# hematocrit_isMissing                                    0.000000
# platelets_isNormal                                      0.000000
# platelets_isIncreased                                   0.000000
# platelets_isDecreased                                   0.000000
# platelets_isNoestimate                                  0.000000
# segmented_neutrophils                                   0.000030
# lymphocytes                                             0.000000
# monocytes                                               0.000000
# eosinophils                                             0.000000
# basophils                                               0.000000
# band_neutrophils                                        0.000000
# cholesterol                                            -0.000022
# cholesterol_isMissing                                   0.000000
# urine_albumin_isNegative                                0.000000
# urine_albumin_is>=30                                    0.000000
# urine_albumin_is>=100                                   0.000000
# urine_albumin_is>=300                                   0.000000
# urine_albumin_is>=1000                                  0.000000
# urine_albumin_isTrace                                   0.000000
# urine_albumin_isBlankbutapplicable                      0.000000
# urine_glucose_isNegative                                0.000000
# urine_glucose_isLight                                   0.000000
# urine_glucose_isMedium                                  0.000000
# urine_glucose_isDark                                    0.000000
# urine_glucose_isVerydark                                0.000000
# urine_glucose_isTrace                                   0.000000
# urine_glucose_isBlankbutapplicable                      0.000000
# urine_pH                                                0.000088
# urine_pH_isBlankbutapplicable                           0.000000
# urine_hematest_isNegative                               0.000000
# urine_hematest_isSmall                                  0.000000
# urine_hematest_isModerate                               0.000000
# urine_hematest_isLarge                                  0.000000
# urine_hematest_isBlankbutapplicable                     0.000000
# sedimentation_rate                                      0.000000
# sedimentation_rate_isBlankbutapplicable                 0.000000
# uric_acid                                               0.000000
# uric_acid_isUnacceptable                                0.000000
# uric_acid_isTestnotdone                                 0.000000
# systolic_blood_pressure                                -0.000027
# pulse_pressure                                         -0.000008
# bmi                                                     0.000000
#
#                                          systolic_blood_pressure  \
# sex_isFemale                                       -3.355864e-02
# age                                                -7.039897e-01
# physical_activity                                  -5.290380e-03
# serum_albumin                                      -3.402938e-02
# alkaline_phosphatase                                2.868190e-02
# alkaline_phosphatase_isUnacceptable                 3.128900e-04
# alkaline_phosphatase_isTestnotdone                 -2.373968e-04
# SGOT                                               -8.371247e-03
# SGOT_isUnacceptable                                 1.590704e-03
# SGOT_isTestnotdone                                  0.000000e+00
# BUN                                                -5.735706e-04
# BUN_isUnacceptable                                 -2.282662e-06
# BUN_isTestnotdone                                  -6.100932e-05
# calcium                                            -1.086132e-03
# calcium_isUnacceptable                              7.100115e-04
# calcium_isTestnotdone                               0.000000e+00
# creatinine                                         -1.015784e-04
# creatinine_isUnacceptable                           0.000000e+00
# creatinine_isTestnotdone                            0.000000e+00
# potassium                                           5.896685e-03
# potassium_isUnacceptable                            6.889488e-05
# sodium                                             -2.587708e-04
# sodium_isUnacceptable                               0.000000e+00
# total_bilirubin                                     1.295255e-03
# total_bilirubin_isUnacceptable                      3.357588e-04
# total_bilirubin_isTestnotdone                      -1.087377e-04
# serum_protein                                      -1.351367e-02
# red_blood_cells                                    -1.001017e-02
# red_blood_cells_isUnacceptable                     -1.338055e-03
# red_blood_cells_isBlankbutapplicable                1.361296e-04
# white_blood_cells                                  -2.650522e-02
# white_blood_cells_isUnacceptable                    0.000000e+00
# white_blood_cells_isBlankbutapplicable              4.025785e-05
# hemoglobin                                          7.242522e-04
# hemoglobin_isMissing                                0.000000e+00
# hematocrit                                         -2.027584e-02
# hematocrit_isUnacceptable                          -6.556167e-06
# hematocrit_isMissing                                0.000000e+00
# platelets_isNormal                                  7.200760e-05
# platelets_isIncreased                              -1.628990e-05
# platelets_isDecreased                               3.942779e-06
# platelets_isNoestimate                              0.000000e+00
# segmented_neutrophils                               3.911652e-04
# lymphocytes                                        -8.804848e-04
# monocytes                                           1.824054e-03
# eosinophils                                        -8.970082e-04
# basophils                                          -1.768025e-04
# band_neutrophils                                   -3.011038e-04
# cholesterol                                        -2.045693e-02
# cholesterol_isMissing                               0.000000e+00
# urine_albumin_isNegative                            7.779726e-04
# urine_albumin_is>=30                               -1.243013e-04
# urine_albumin_is>=100                              -2.094135e-03
# urine_albumin_is>=300                               1.533534e-04
# urine_albumin_is>=1000                              0.000000e+00
# urine_albumin_isTrace                              -1.046082e-03
# urine_albumin_isBlankbutapplicable                  4.399312e-05
# urine_glucose_isNegative                            1.493556e-02
# urine_glucose_isLight                               0.000000e+00
# urine_glucose_isMedium                              1.272584e-04
# urine_glucose_isDark                                3.721880e-03
# urine_glucose_isVerydark                            4.952027e-03
# urine_glucose_isTrace                              -1.245088e-06
# urine_glucose_isBlankbutapplicable                  0.000000e+00
# urine_pH                                            2.700933e-03
# urine_pH_isBlankbutapplicable                       0.000000e+00
# urine_hematest_isNegative                          -1.556360e-04
# urine_hematest_isSmall                              2.780697e-05
# urine_hematest_isModerate                          -8.300588e-07
# urine_hematest_isLarge                             -3.320235e-06
# urine_hematest_isBlankbutapplicable                 0.000000e+00
# sedimentation_rate                                 -2.782889e-02
# sedimentation_rate_isBlankbutapplicable             1.311493e-04
# uric_acid                                           1.953669e-02
# uric_acid_isUnacceptable                            2.739194e-05
# uric_acid_isTestnotdone                            -2.656188e-05
# systolic_blood_pressure                             0.000000e+00
# pulse_pressure                                     -1.642711e-01
# bmi                                                -1.823997e-02
#
#                                          pulse_pressure           bmi
# sex_isFemale                              -2.769595e-03 -2.625185e-02
# age                                        3.662510e-02 -2.401526e-02
# physical_activity                         -3.928461e-03 -1.159836e-02
# serum_albumin                             -2.837861e-03 -4.234735e-03
# alkaline_phosphatase                       3.935840e-04  5.874119e-03
# alkaline_phosphatase_isUnacceptable        0.000000e+00  0.000000e+00
# alkaline_phosphatase_isTestnotdone        -3.309859e-05  5.416133e-05
# SGOT                                       2.195003e-03  1.815079e-03
# SGOT_isUnacceptable                        5.056355e-04  1.459347e-04
# SGOT_isTestnotdone                        -2.228189e-04 -8.715617e-06
# BUN                                        2.481279e-03  8.416277e-04
# BUN_isUnacceptable                         0.000000e+00  0.000000e+00
# BUN_isTestnotdone                          0.000000e+00 -2.075147e-07
# calcium                                    1.976658e-03 -4.947669e-04
# calcium_isUnacceptable                    -7.444589e-06  5.089428e-04
# calcium_isTestnotdone                      0.000000e+00 -3.112720e-06
# creatinine                                -6.071361e-04  9.045566e-04
# creatinine_isUnacceptable                  0.000000e+00  0.000000e+00
# creatinine_isTestnotdone                   0.000000e+00  0.000000e+00
# potassium                                 -7.104071e-03 -1.358339e-03
# potassium_isUnacceptable                  -7.641728e-05 -1.037573e-05
# sodium                                    -9.890669e-05  9.971599e-04
# sodium_isUnacceptable                      0.000000e+00  0.000000e+00
# total_bilirubin                           -2.397168e-03 -3.374448e-03
# total_bilirubin_isUnacceptable             0.000000e+00  1.031244e-03
# total_bilirubin_isTestnotdone             -8.028224e-06 -9.026889e-06
# serum_protein                              4.734432e-03  3.789737e-05
# red_blood_cells                           -6.361908e-03 -3.376829e-02
# red_blood_cells_isUnacceptable            -4.889721e-03  2.925957e-05
# red_blood_cells_isBlankbutapplicable       0.000000e+00  2.773434e-04
# white_blood_cells                         -2.297146e-03  8.778598e-03
# white_blood_cells_isUnacceptable          -5.628836e-06  0.000000e+00
# white_blood_cells_isBlankbutapplicable     0.000000e+00  3.110645e-04
# hemoglobin                                -3.291825e-03 -7.517375e-03
# hemoglobin_isMissing                       0.000000e+00  0.000000e+00
# hematocrit                                -1.800605e-03 -7.265763e-03
# hematocrit_isUnacceptable                 -4.974841e-04 -3.199877e-04
# hematocrit_isMissing                       0.000000e+00 -2.075147e-05
# platelets_isNormal                         0.000000e+00  1.449490e-04
# platelets_isIncreased                     -7.833680e-06 -4.606826e-05
# platelets_isDecreased                     -1.069998e-05 -1.075445e-04
# platelets_isNoestimate                     0.000000e+00  0.000000e+00
# segmented_neutrophils                     -2.578649e-03  1.275048e-04
# lymphocytes                               -6.759532e-04  2.293582e-03
# monocytes                                 -3.176791e-04 -1.211315e-03
# eosinophils                                6.591891e-04 -3.533310e-03
# basophils                                  6.497804e-05  1.736898e-04
# band_neutrophils                          -1.826932e-04  1.220705e-04
# cholesterol                               -2.366498e-03 -2.890680e-04
# cholesterol_isMissing                      0.000000e+00  0.000000e+00
# urine_albumin_isNegative                  -5.251548e-04 -3.730699e-03
# urine_albumin_is>=30                      -4.060284e-04 -2.075666e-04
# urine_albumin_is>=100                     -3.943817e-04 -3.504508e-03
# urine_albumin_is>=300                     -4.279991e-07 -5.153524e-03
# urine_albumin_is>=1000                    -1.621209e-07  0.000000e+00
# urine_albumin_isTrace                     -7.996254e-04  7.092333e-04
# urine_albumin_isBlankbutapplicable        -1.245737e-04  0.000000e+00
# urine_glucose_isNegative                  -4.768428e-04 -2.580367e-03
# urine_glucose_isLight                      0.000000e+00 -4.420063e-05
# urine_glucose_isMedium                    -3.190538e-06 -9.072543e-04
# urine_glucose_isDark                      -7.775802e-04 -6.691830e-04
# urine_glucose_isVerydark                  -1.497074e-03 -1.073681e-03
# urine_glucose_isTrace                     -2.593934e-07 -3.828646e-05
# urine_glucose_isBlankbutapplicable         0.000000e+00  0.000000e+00
# urine_pH                                   1.891723e-03  6.012323e-03
# urine_pH_isBlankbutapplicable              9.906232e-05  0.000000e+00
# urine_hematest_isNegative                 -1.291455e-05 -5.645437e-04
# urine_hematest_isSmall                     1.920548e-04 -6.619719e-05
# urine_hematest_isModerate                  1.395536e-05  8.902380e-05
# urine_hematest_isLarge                     0.000000e+00 -5.042607e-05
# urine_hematest_isBlankbutapplicable        0.000000e+00  0.000000e+00
# sedimentation_rate                        -9.834653e-03 -2.208475e-04
# sedimentation_rate_isBlankbutapplicable   -2.440814e-03  2.699092e-03
# uric_acid                                 -8.560500e-04 -1.563774e-02
# uric_acid_isUnacceptable                   4.028379e-05  6.650846e-05
# uric_acid_isTestnotdone                   -7.522408e-06  0.000000e+00
# systolic_blood_pressure                   -1.642709e-01 -1.823893e-02
# pulse_pressure                             0.000000e+00 -3.947967e-04
# bmi                                       -3.946629e-04  0.000000e+00

# %% [markdown]
# ## Visualization

# %%
shap_cmap = shap.plots.colors.red_blue
positive_color = shap_cmap(0.0)[:3]
negative_color = shap_cmap(1.0)[:3]

positive_alpha = 0.01
negative_alpha = 0.01
positive_beta = 0
negative_beta = 0

# %%
positive_color
# Out:
# (np.float64(0.0),
#  np.float64(0.5433775692459107),
#  np.float64(0.983379062301401))

# %%
draw(
    psi=psi_2,
    r=r_2,
    psi_q25=psi_1_median,
    psi_q75=psi_1_median,
    r_q25=r_1_q_lower,
    r_q75=r_1_q_upper,
    positive_alpha=positive_alpha,
    negative_alpha=negative_alpha,
    positive_beta=positive_beta,
    negative_beta=negative_beta,
    negative_color=negative_color,
    positive_color=positive_color,
    uncertain_color='grey',
    output_path=os.path.join('..', '..', 'result', 'nhanesi_xgboost_iqr_gamma_5_network.jpg')
)
# Out:
# Saving the graph to ..\..\result\nhanesi_xgboost_iqr_gamma_5_network.jpg
