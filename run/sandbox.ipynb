# %%
import shap
import numpy as np

shap_cmap = shap.plots.colors.red_blue
positive_color = shap_cmap(0.0)[:3]
negative_color = shap_cmap(1.0)[:3]
display(np.multiply(positive_color, 255))
display(np.multiply(negative_color, 255))
# Out:
# array([  0.        , 138.56128016, 250.76166089])
# array([255.        ,   0.        ,  81.08083606])
